# %%
# Pandas
import pandas as pd

# Import dependencies
from PyPDF2 import PdfFileReader

# spaCY for NLP
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# Import Heapq 
from heapq import nlargest

# Import HuggingFace Transformer
from transformers import pipeline


# Import Google's T5 Model Transformer
from transformers import TFAutoModelWithLMHead, AutoTokenizer


# NLTK for splitting sentences
import nltk.data

#textblob
from textblob import TextBlob


# Incompatabilties with spaCy 3.0
from spacytextblob.spacytextblob import SpacyTextBlob


#Regex
import re

# Pretty Print
import pprint

# %%
# Read the sample file and create the PDF Object

pdf_path='data/sample.pdf'
pdf = PdfFileReader(str(pdf_path))
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %% [markdown]
# #### Preview PDF

# %%
def _embed_pdf_html(pdf, size):
    return '<iframe src={0} width={1[0]} height={1[1]}></iframe>'.format(pdf, size)

# %%
print(_embed_pdf_html('./data/sample.pdf',size=(300,250)))
# Out:
# <iframe src=./data/sample.pdf width=300 height=250></iframe>

# %%
# total num of pages in PDF
print(pdf.numPages)
# Out:
# 19

# %%
# Get 5th Page. PDF is 0-indexed, so 5th page is at 4th index
pdf.getPage(4).extractText()
# Out:
# '4Rewriting the rules: Succeeding in the new retail banking landscape \nWithin any specific market, of course, there are \nbanks that have acted swiftly to adopt digital and \nremote as their main channel for interactions, and \n\nthose that have lagged behind (Exhibit 4, page 6). One UK bank makes more than 50 percent of sales \n\nthrough digital channels, well ahead of market peers. \n\nEven in the historically branch-dependent small \nbusiness segment, a range of banks and fintechs are \n\nfinding that remote value propositions delivered \n\ndigitally (e.g., remote relationship managers at Nordic \n\nbanks) are attractive to small businesses. \nBanks that are ahead of the curve in terms of \ncapitalizing on this shift are pulling away from the \n\npack and have taken decisive actions on several \nfronts:  \n  Set a bold aspiration for sales/service channel \nmix. Banks must do more than react to shifts \nin consumer preferences—they need to set \n\naspirational targets for sales and service \nacross channels. Some customers will self-\n\nselect into digital channels, but banks can do 2016\n0210\n082000\n400\n04500\n700\n0612\n800\n9001,000\n14600\n200\n0100\n300\nUKCanada\nFinland\nPortugal\nSpainGermany\nNetherlands\nItaly\nSweden\nDenmarkGreece\nUSBank branches \nper million people\n1Branches \n\nper million \n\npeople2Peak-to-\n\ntrough \n\nreduction\n 625\nSpain38%\n 494Portugal27%\n 486\nItaly16%\n 358Germany37%\n 306\nUS17%\n161\nCanada11%\n 213\nGreece42%\n 196\nDenmark56%\n 192\nFinland45%\n 183\nSweden22%\n 153\nUK37%\nNetherlands 9971%\nExhibit 2\n1 Represents bank branch density per million people in the country.\n2 Based on 2016 or latest year available.\nSource: McKinsey World Banking Intelligence database; McKinsey analysis\nThe number of branches per million people is declining in North \nAmerica, the UK, and Europe.\n'

# %% [markdown]
# ## Read and Extract PDF

# %%
with open('data/extract_2.txt',mode="w") as output_file:
    for page in pdf.pages:
        text = page.extractText()
        
        output_file.write(text)

# %% [markdown]
# ## Clean Text

# %%
def clean_text(filename, isFile = True):
    if isFile:
        fp = open(filename)
        data = fp.read().replace('\n', '')
    else:
        data = filename
        
    return re.sub(r"([0-9]+(\.[0-9]+)?)",r" \1 ", data).strip()

# %% [markdown]
# ### Sampled Sentences

# %%
document1 ="""Succeeding in the new retail banking landscape Retail banks have long competed on distribution, realizing economies of scale through network effects and investments in brand and infrastructure. But even those scale economies had limits above a certain size. As a result, in most retail banking markets, a few large institutions, operating at similar efficiency ratios, dominate market share. Changes to the retail banking business model have mostly come in response to regulatory shifts, as opposed to a purposeful reimagining of what the winning bank of the future will look like. Retail banks have also not kept pace with the improvements in customer experience seen in other consumer industries. Few banks stand out for innovation in customer interaction models or branch formats. Marketing investments have traditionally focused on brand building and increasing loyalty: a reputable brand stood for trust and security and became a moat, providing protection against new entrants to the sector. Finally, most banks offer similar products, with limited innovation in features. Today, the moats that banks have built are more likely to restrict their own progress than protect them from attackers. Four shifts are reshaping the global retail banking landscape to the point where banks need to fundamentally rethink what it takes to compete and win. This should be an urgent priority for banks. The pace of change will likely accelerate, with a select set of large-scale winners emerging in the next three to five years that will gain share in their core markets and begin to compete across borders, leaving many sub-scale institutions scrambling for relevance. Rewriting the rules: Succeeding in the new retail banking landscape 2Rewriting the rules: Succeeding in the new retail banking landscape Four shifts are reshaping retail banking Four secular shifts are changing the way retail banks will compete in the coming years:    The traditional distribution-led growth formula is losing relevance, with a breakdown in the relationship between branch footprint and growth. Banks are now competing on customer experience, with leaders growing faster than their competitors.    Scale economics are back—banks that excel at deploying new technologies (e.g., automation and machine learning) and those with a more digital-centric channel mix will have a structural cost advantage.    The retail banking relationship is getting unbundled along product lines, fueled by digitization and, increasingly, by regulation— and the biggest profit pools are under attack. A few banks will be able to temper and reverse this trend, using superior data and analytics capabilities to build deeper and broader relationships with their customers. In the near term, these shifts will combine to intensify competition as new entrants and incumbents seek to push past traditional boundaries. More than 100 digital attacker banks have launched in the last few years globally— including N26, Monzo and Revolut in Europe; WeBank, Digibank, Jenius in Asia; SoFi, Marcus, Moven in the US; Nubank in South America— while many incumbents have launched or are considering launching digital-first models.  Over the next three to five years, we expect a few players to emerge from this competitive scrum to gain dominant share in their core markets and possibly beyond. These firms will have taken bold and decisive actions to capitalize on the shifts that are reshaping the industry. In some cases, these winners will be incumbents that build on an already significant share; in others, they will be institutions newer to the banking industry, which use their agility, strategic aggressiveness, and sharp execution to attract customers.   1. The traditional distribution-led growth formula no longer applies Until the financial crisis in 2007, a retail bank’s total share of deposits was tightly linked to the size of its branch network. Even as internet use grew rapidly, customers still visited branches for account servicing and to learn about and purchase new products. The physical branch created a sense of security and trust. Banks with higher branch density benefited from a network effect—the more branches, the higher the likelihood of acquiring and retaining customers. Over the past decade, this relationship between deposit growth and branch density has weakened. Deposits at the 25 largest US retail banks have doubled over the past decade, while their combined branch footprint shrank by 15 percent over the same period. This reverse correlation is even sharper for the top five US banks—while reducing branches by 15 percent, they increased deposits by 2.6 times ( Exhibit 1). While there have been previous periods of branch contraction, they were clearly tied to economic downturns; this most recent wave of retrenchment commenced about a decade ago and has persisted through a period of robust economic growth. Retail banking branch networks are contracting across North America, the UK, and Europe (Exhibit 2, page 4), although the pace of change varies considerably between regions. Those that are ahead of the curve have reduced branches by as much as 71 percent (Netherlands). Banks in North America and Southern Europe are 3Rewriting the rules: Succeeding in the new retail banking landscape reducing branches and growing digital sales at a more gradual rate. In many Asian, African, and Latin American countries, branch reduction is not so apparent—only because retail banks in these markets leapfrogged branch distribution to go directly to digital sales. The rate of branch reduction is often tied to customer willingness to purchase banking products online or on mobile devices. Eighty to ninety percent of banking customers in the Nordics, for example, are open to digital product purchases for most financial products, compared to 50 to 60 percent in North America and Southern Europe ( Exhibit 3, page 5). While customer willingness to purchase products via digital channels varies, however, the common thread is that in all markets this readiness is far ahead of actual digital sales and will require banks to catch up to consumer needs and expectations."""

# %%
document2 = """Customer experience is beginning to gener- ate meaningful separation in growth Across all retail businesses—including banks— customers now expect interactions to be simple, intuitive, and seamlessly connected across physical and digital touchpoints.  Banks are investing in meeting these expectations but have struggled to keep pace—focusing on the less-than-lofty goal of making the experience “less bad” for customers, rather than “outstanding.” Many banks are hampered by legacy IT infrastructures and siloed data. As a result, few banks are true leaders in terms of customer experience. Even for leading institutions, typically only one-half to two-thirds of customers rate their experience as excellent. This holds true across product categories, including those such as cards and deposits that have higher digital adoption rates.  The impact of this less-than-stellar performance is measurable. For example, McKinsey analysis shows that in the US, top-quartile banks in terms of experience have had meaningfully higher deposit growth over the past three years ( Exhibit 5, page 8). Simply being good does not move the needle; customer impact really shows when banks offer outstanding experiences. The few “experience leaders” emerging in retail banking are generating higher growth than their peers by attracting new customers and deepening relationships with their existing customer base. Highly satisfied customers are two-and-a-half times more likely to open new accounts/products with their existing bank than those who are merely satisfied; they are also less price sensitive and generate positive word of mouth. These experience leaders are adopting tactics pioneered by digital-native companies in other sectors such as ecommerce, travel, and entertainment: setting a “north star” based on proven markers of differentiated experience (e.g., UX design, carrying context across channels), redesigning journeys that matter most for digital- first customers and not just digital-only customers, and establishing integrated real-time measurement that cuts across products, channels, and employees. These banks know that customer experience is not just about the front- end look and feel, but that it requires discipline, focus, and investment in the following actions:    Focus on the journeys and sub-journeys that matter: The relative contribution of sub- journeys (e.g., app downloading; activating account) in determining overall customer experience varies considerably. In fact, ten to fifteen sub-journeys have the biggest customer satisfaction impact for most products and should thus be the first priority. For instance, when opening a new deposit account, the researching options sub-journey has eight times the impact on customer satisfaction than other account-opening sub- journeys, on average ( Exhibit 6, page 9). For banks, the key is to prioritize these high- impact sub-journeys and systematically redesign them from scratch—a process that can take about three to four months and result in at least a 15 to 20 percent lift in customer satisfaction.   Change the way you engage with customers. Experience leaders understand that digitization is not just about creating a cutting-edge online and mobile experience, and that satisfaction is shaped by customer experience across channels.1 The experience should be seamless, especially on journeys that are more likely to take place over multiple channels, such as new account opening, financial 1  Walter Rizzi and Zubin Taraporevala, “The balancing act: Omnichannel excellence in retail banking,” McKinsey.com, January 2019. 8Rewriting the rules: Succeeding in the new retail banking landscape advice, or issue resolution. One wealth manager equipped its front-line relationship managers with robo-advice algorithms that are in sync with what customers see on the self- directed channel—and provided the RMs with daily and weekly next-best-action recommendations to nudge their clients. Banks need to deploy these tools broadly and empower their front-line staff to play a more consultative role that blends human and digital recommendations. They will also need to revisit how these employees are incentivized, shifting to a longer-term view of relationships and profitability rather than just product sales. Translate data into personalized products and real-time offers. The amount of data available on individual customers or prospects has exploded in recent years. The challenge is to convert this data into actionable nudges and highly relevant offers for customers that are delivered at the right moment. Credit card companies have long offered discounts on specific spending categories or with specific retailers. Today, however, they can improve loyalty and share of spending by providing location-specific offers right when a customer enters a coffee shop, movie theater, or car dealership. South Real differences in customer satisfaction 1CSAT (Percent of customers rating 9 or 10) Leaders in customer experience are growing faster Deposit CAGR (2014-17) 65554939-26 5.93.2 46% Top quartile CSAT Bottom quartile CSAT Bottom quartile 3rdquartile 2nd quartile Top quartile Exhibit 5 1 Percentage of respondents that selected a 9 or 10 on a 10-point customer satisfaction scale. Question: “We would like to understand your experience with [product] with [Bank]. Overall, how satised or dissatised are you with [product] with [Bank]? ”Source: McKinsey 2018 Retail Banking Customer Experience Benchmark Survey. US retail banks with better customer experience are growing deposits faster. 9Rewriting the rules: Succeeding in the new retail banking landscape Africa’s Discovery, as an example, is launching a bank with product features that are informed by behavioral science and incentive design research (e.g., dynamic interest rates for savings and credit products that are tied to healthy financial behavior). 3. Productivity gains and returns to scale are back Larger retail banks have historically tended to be more efficient than their smaller competitors, benefiting from distribution network effects and the shared overhead for IT, infrastructure, and other shared services. Our analysis of over 3,000 515 01020253040 3545 5050055606570Importance Relative importance % 3Researching options Deposit sub-journeys 1Downloading the app Activating the account Learning about account features Completing the application Performance Journey SAT (top 2 boxes) 2Exhibit 6 1 Deposit example journeys shown; trend also holds true for credit card and mortgage account-opening sub-journeys. 2 Customer satisfaction with individual sub-journeys. Represents percentage of customers that rated the sub-journey 9 or 10 (on 10-point scale). 3 Relative importance is the amount that any individual sub-journey impacts the total journey score; calculated using a variance decomposition approach. Source: McKinsey 2018 North American Retail Banking Journey Benchmarks Banks should prioritize the sub-journeys the have the most impact on customer experience. 10Rewriting the rules: Succeeding in the new retail banking landscape banks around the globe shows that while there is variation across countries, larger institutions tend to be more efficient both in terms of cost-to-asset (Exhibit 7) and cost-to-income ratios. However, beyond a certain point, even larger institutions struggle to eke out efficiencies or realize benefits from scale. For example, even after several years of cost-cutting after the most recent financial crisis, large US retail banks have not made material improvements in productivity over the past decade (Exhibit 8).   We expect this paradigm to change over the next few years, as structural improvements in efficiency ratios and increasing returns to scale enable some large banks to become even more efficient. The reason is two-fold: first, advances in technologies such as robotic process automation, machine learning, and cognitive artificial intelligence—many of which are now mainstream and commercially viable—are unleashing a new wave of productivity improvements for financial institutions."""

# %% [markdown]
# # Using spaCy

# %%
def generate_summary(input_text, mode="FAST"):
    
    if mode is "ACCURACY": # Use different models, accurate models are slower 
        nlp = spacy.load('en_core_web_trf')
    else:
        nlp = spacy.load('en_core_web_sm')
        
        
    doc_obj = nlp(input_text)
    stopwords = list(STOP_WORDS)

    word_freq = {}  
    for word in doc_obj:  
        if word.text not in stopwords:
            if word.text not in word_freq.keys():
                word_freq[word.text] = 1
            else:
                word_freq[word.text] += 1


    max_freq = max(word_freq.values())

    for word in word_freq.keys():  
        word_freq[word] = (word_freq[word]/max_freq)

    # Sentence Tokens
    sentence_list = [ sentence for sentence in doc_obj.sents ]

    # Calculate Sentence Score and Ranking
    sentence_scores = {}  
    for sent in sentence_list:  
        for word in sent:
            if word.text.lower() in word_freq.keys():
                if len(sent.text.split(' ')) < 30:
                    if sent not in sentence_scores.keys():
                        sentence_scores[sent] = word_freq[word.text.lower()]
                    else:
                        sentence_scores[sent] += word_freq[word.text.lower()]

    # Find N Largest
    summary_sentences = nlargest(7, sentence_scores, key=sentence_scores.get)
    final_sentences = [ w.text for w in summary_sentences ]
    summary = ' '.join(final_sentences)
    
    print("Original Text\n")
    print(input_text)
    print("\n Original Total Length:",len(input_text))
    print('\n\nSummarized Text\n')
    print(summary)
    print("\nSummary Total Length:",len(summary))

# %% [markdown]
# ## Summarization

# %%
generate_summary(document1, "FAST")
# Out:
# Original Text
#
# Succeeding in the new retail banking landscape Retail banks have long competed on distribution, realizing economies of scale through network effects and investments in brand and infrastructure. But even those scale economies had limits above a certain size. As a result, in most retail banking markets, a few large institutions, operating at similar efficiency ratios, dominate market share. Changes to the retail banking business model have mostly come in response to regulatory shifts, as opposed to a purposeful reimagining of what the winning bank of the future will look like. Retail banks have also not kept pace with the improvements in customer experience seen in other consumer industries. Few banks stand out for innovation in customer interaction models or branch formats. Marketing investments have traditionally focused on brand building and increasing loyalty: a reputable brand stood for trust and security and became a moat, providing protection against new entrants to the sector. Finally, most banks offer similar products, with limited innovation in features. Today, the moats that banks have built are more likely to restrict their own progress than protect them from attackers. Four shifts are reshaping the global retail banking landscape to the point where banks need to fundamentally rethink what it takes to compete and win. This should be an urgent priority for banks. The pace of change will likely accelerate, with a select set of large-scale winners emerging in the next three to five years that will gain share in their core markets and begin to compete across borders, leaving many sub-scale institutions scrambling for relevance. Rewriting the rules: Succeeding in the new retail banking landscape 2Rewriting the rules: Succeeding in the new retail banking landscape Four shifts are reshaping retail banking Four secular shifts are changing the way retail banks will compete in the coming years:    The traditional distribution-led growth formula is losing relevance, with a breakdown in the relationship between branch footprint and growth. Banks are now competing on customer experience, with leaders growing faster than their competitors.    Scale economics are back—banks that excel at deploying new technologies (e.g., automation and machine learning) and those with a more digital-centric channel mix will have a structural cost advantage.    The retail banking relationship is getting unbundled along product lines, fueled by digitization and, increasingly, by regulation— and the biggest profit pools are under attack. A few banks will be able to temper and reverse this trend, using superior data and analytics capabilities to build deeper and broader relationships with their customers. In the near term, these shifts will combine to intensify competition as new entrants and incumbents seek to push past traditional boundaries. More than 100 digital attacker banks have launched in the last few years globally— including N26, Monzo and Revolut in Europe; WeBank, Digibank, Jenius in Asia; SoFi, Marcus, Moven in the US; Nubank in South America— while many incumbents have launched or are considering launching digital-first models.  Over the next three to five years, we expect a few players to emerge from this competitive scrum to gain dominant share in their core markets and possibly beyond. These firms will have taken bold and decisive actions to capitalize on the shifts that are reshaping the industry. In some cases, these winners will be incumbents that build on an already significant share; in others, they will be institutions newer to the banking industry, which use their agility, strategic aggressiveness, and sharp execution to attract customers.   1. The traditional distribution-led growth formula no longer applies Until the financial crisis in 2007, a retail bank’s total share of deposits was tightly linked to the size of its branch network. Even as internet use grew rapidly, customers still visited branches for account servicing an ...
#
#  Original Total Length: 6156
#
#
# Summarized Text
#
# Retail banking branch networks are contracting across North America, the UK, and Europe (Exhibit 2, page 4), although the pace of change varies considerably between regions. As a result, in most retail banking markets, a few large institutions, operating at similar efficiency ratios, dominate market share. In many Asian, African, and Latin American countries, branch reduction is not so apparent—only because retail banks in these markets leapfrogged branch distribution to go directly to digital sales. The retail banking relationship is getting unbundled along product lines, fueled by digitization and, increasingly, by regulation— and the biggest profit pools are under attack. Succeeding in the new retail banking landscape Retail banks have long competed on distribution, realizing economies of scale through network effects and investments in brand and infrastructure. Finally, most banks offer similar products, with limited innovation in features. Deposits at the 25 largest US retail banks have doubled over the past decade, while their combined branch footprint shrank by 15 percent over the same period.
#
# Summary Total Length: 1117

# %%
#generate_summary(document2, "ACCURACY")

# %% [markdown]
# ## Named Entity Recognition

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(document1)
_table = []

for ent in doc.ents:
    _row = []
    _row.append(ent.text)
    _row.append(ent.start_char)
    _row.append(ent.end_char)
    _row.append(ent.label_)
    
    _table.append(_row)
    #print(ent.text, ent.start_char, ent.end_char, ent.label_)

pd.DataFrame(_table, columns=["TEXT", "START_CHAR", "END_CHAR", "LABEL"])
# Out:
#                             TEXT  START_CHAR  END_CHAR     LABEL
# 0                          Today        1079      1084      DATE
# 1                           Four        1199      1203  CARDINAL
# 2   the next three to five years        1491      1519      DATE
# 3                     2Rewriting        1730      1740  CARDINAL
# 4                           Four        1799      1803  CARDINAL
# 5                           Four        1840      1844  CARDINAL
# 6               the coming years        1910      1926      DATE
# 7                          Scale        2177      2182       GPE
# 8                  More than 100        2871      2884  CARDINAL
# 9             the last few years        2925      2943      DATE
# 10                           N26        2964      2967       ORG
# 11                         Monzo        2969      2974     EVENT
# 12                       Revolut        2979      2986       ORG
# 13                        Europe        2990      2996       LOC
# 14                        WeBank        2998      3004       ORG
# 15                      Digibank        3006      3014       ORG
# 16                          Asia        3026      3030       LOC
# 17                          SoFi        3032      3036       ORG
# 18                 Marcus, Moven        3038      3051       ORG
# 19                            US        3059      3061       GPE
# 20                        Nubank        3063      3069       GPE
# 21                 South America        3073      3086       LOC
# 22                         first        3161      3166   ORDINAL
# 23  the next three to five years        3181      3209      DATE
# 24                             1        3709      3710  CARDINAL
# 25                          2007        3808      3812      DATE
# 26               the past decade        4256      4271      DATE
# 27                            25        4363      4365  CARDINAL
# 28                            US        4374      4376       GPE
# 29               the past decade        4408      4423      DATE
# 30                    15 percent        4473      4483   PERCENT
# 31               the same period        4489      4504      DATE
# 32                          five        4559      4563  CARDINAL
# 33                            US        4564      4566       GPE
# 34                    15 percent        4600      4610   PERCENT
# 35                           2.6        4639      4642  CARDINAL
# 36            about a decade ago        4819      4837      DATE
# 37                 North America        4954      4967       LOC
# 38                            UK        4973      4975       GPE
# 39                        Europe        4981      4987       LOC
# 40                             4        5005      5006  CARDINAL
# 41         as much as 71 percent        5133      5154   PERCENT
# 42                   Netherlands        5156      5167       GPE
# 43                 North America        5179      5192       LOC
# 44               Southern Europe        5197      5212       LOC
# 45                    3Rewriting        5217      5227  CARDINAL
# 46                         Asian        5362      5367      NORP
# 47                       African        5369      5376      NORP
# 48                Latin American        5382      5396      NORP
# 49      Eighty to ninety percent        5677      5701      DATE
# 50                       Nordics        5730      5737       ORG
# 51              50 to 60 percent        5831      5847   PERCENT
# 52                 North America        5851      5864       LOC
# 53               Southern Europe        5869      5884       LOC
# 54                             5        5903      5904  CARDINAL

# %% [markdown]
# # Using HuggingFace Transformers (SoA)

# %%
# Initialize the HuggingFace summarization pipeline
summarizer = pipeline("summarization")
# Out:
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at t5-small.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %% [markdown]
# # Read PDF Line-by-line and SUMMARIZE

# %%
# Be careful before running, this - this cell takes time!

page_count = 1

for page in pdf.pages:
    text = page.extractText()
    
    #Config the HF Summarization pipeline
    summarized_text = summarizer(text, min_length=75, max_length=300)
    
    # Print summarized text
    print("\n---- Page No. " + str(page_count) + "----")
    print ("Original Text Length: " + str(len(text)))
    print("Original Text: " + text)
    print ("--")
    print ("Summarized Text Length: " + str(len(summarized_text[0]['summary_text'])))
    print(summarized_text[0]['summary_text'])
    page_count += 1
# Out:
# Your max_length is set to 300, but you input_length is only 44. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# ---- Page No. 1----
# Original Text Length: 166
# Original Text: Rewriting the rules: Succeeding in the
# new retail banking
#
# landscape  Authored by:
# Vaibhav Gujral
# Nick Malik
# Zubin Taraporevala
# Global Banking  February 2019
# --
# Summarized Text Length: 286
# rewriting the rules: Succeeding in the new retail banking landscape Authored by: Vaibhav Gujral Nick Malik Zubin Taraporevala Global Banking February 2019 . the rules are based on the rules of the retail banking industry . it is the first time the banking landscape has been rewritten .
# Token indices sequence length is longer than the specified maximum sequence length for this model (714 > 512). Running this sequence through the model will result in indexing errors
# ---- Page No. 2----
# Original Text Length: 1809
# Original Text: 1Rewriting the rules: Succeeding in the new retail banking landscape
# Retail banks have long competed on distribution, realizing economies of scale through network
#
# effects and investments in brand and
#
# infrastructure. But even those scale economies
#
# had limits above a certain size. As a result, in
#
# most retail banking markets, a few large
#
# institutions, operating at similar efficiency ratios,
#
# dominate market share. Changes to the retail
#
# banking business model have mostly come in
# response to regulatory shifts, as opposed to a
#
# purposeful reimagining of what the winning bank
#
# of the future will look like.
# Retail banks have also not kept pace with the improvements in customer experience seen in
#
# other consumer industries. Few banks stand out
# for innovation in customer interaction models or
# branch formats. Marketing investments have
# traditionally focused on brand building and increasing loyalty: a reputable brand stood for
# trust and security and became a moat, providing
#
# protection against new entrants to the sector.
#
# Finally, most banks offer similar products, with
#
# limited innovation in features.
# Today, the moats that banks have built are more
# likely to restrict their own progress than protect
#
# them from attackers. Four shifts are reshaping
#
# the global retail banking landscape to the point
#
# where banks need to fundamentally rethink what
#
# it takes to compete and win. This should be an
# urgent priority for banks. The pace of change will
# likely accelerate, with a select set of large-scale
# winners emerging in the next three to five years
#
# that will gain share in their core markets and
#
# begin to compete across borders, leaving many
#
# sub-scale institutions scrambling for relevance.
# Rewriting the rules: Succeeding in the new retail banking landscape
#
# --
# Summarized Text Length: 480
# banks have long competed on distribution, realizing economies of scale through network effects and investments in brand and infrastructure . but even those scale economies had limits above a certain size . change to the retail banking business model has mostly come in response to regulatory shifts, as opposed to a purposeful reimagining of what the winning bank of the future will look like . few banks stand out for innovation in customer interaction models or branch formats .
#
# ---- Page No. 3----
# Original Text Length: 3601
# Original Text: 2Rewriting the rules: Succeeding in the new retail banking landscape
# Four shifts are reshaping retail
# banking Four secular shifts are changing the way retail
# banks will compete in the coming years:    The traditional distribution-led growth
# formula is losing relevance, with a
# breakdown in the relationship between
#
# branch footprint and growth.
#   Banks are now competing on customer
# experience, with leaders growing faster than
# their competitors.    Scale economics are back—banks that excel
# at deploying new technologies (e.g., automation and machine learning) and those
#
# with a more digital-centric channel mix will
#
# have a structural cost advantage.    The retail banking relationship is getting
# unbundled along product lines, fueled by
# digitization and, increasingly, by regulation—
#
# and the biggest profit pools are under attack.
#
# A few banks will be able to temper and
# reverse this trend, using superior data and
#
# analytics capabilities to build deeper and
# broader relationships with their customers.
# In the near term, these shifts will combine to intensify competition as new entrants and
# incumbents seek to push past traditional
# boundaries. More than 100 digital attacker banks
#
# have launched in the last few years globally—
# including N26, Monzo and Revolut in Europe;
#
# WeBank, Digibank, Jenius in Asia; SoFi, Marcus,
#
# Moven in the US; Nubank in South America—
# while many incumbents have launched or are
#
# considering launching digital-first models.  Over the next three to five years, we expect a
# few players to emerge from this competitive
#
# scrum to gain dominant share in their core
#
# markets and possibly beyond. These firms will
# have taken bold and decisive actions to
# capitalize on the shifts that are reshaping the
# industry. In some cases, these winners will be
# incumbents that build on an already significant
#
# share; in others, they will be institutions newer to
#
# the banking industry, which use their agility,
#
# strategic aggressiveness, and sharp execution to
#
# attract customers.   1. The traditional distribution-led growth formula
#
# no longer applies Until the financial crisis in 2007, a retail bank’s
#
# total share of deposits was tightly linked to the
#
# size of its branch network. Even as internet use
#
# grew rapidly, customers still visited branches for
#
# account servicing and to learn about and
#
# purchase new products. The physical branch
#
# created a sense of security and trust. Banks with
#
# higher branch density benefited from a network
#
# effect—the more branches, the higher the
#
# likelihood of acquiring and retaining customers.
# Over the past decade, this relationship between
# deposit growth and branch density has
#
# weakened. Deposits at the 25 largest US retail
#
# banks have doubled over the past decade, while
# their combined branch footprint shrank by 15
# percent over the same period. This reverse
#
# correlation is even sharper for the top five US
#
# banks—while reducing branches by 15 percent,
#
# they increased deposits by 2.6 times (
# Exhibit 1). While there have been previous periods of
#
# branch contraction, they were clearly tied to
#
# economic downturns; this most recent wave of
#
# retrenchment commenced about a decade ago
#
# and has persisted through a period of robust
#
# economic growth.
# Retail banking branch networks are contracting
# across North America, the UK, and Europe
#
# (Exhibit 2, page 4), although the pace of change varies considerably between regions. Those that
#
# are ahead of the curve have reduced branches
#
# by as much as 71 percent (Netherlands). Banks
#
# in North America and Southern Europe are
#
# --
# Summarized Text Length: 419
# the traditional distribution-led growth formula no longer applies Until the financial crisis in 2007, a retail bank’s total share of deposits was tightly linked to the size of its branch network . this reverse correlation is even sharper for the top five US banks—while reducing branches by 15 percent, they increased deposits by 2.6 times over the same period . the pace of change varies considerably between regions .
#
# ---- Page No. 4----
# Original Text Length: 1602
# Original Text: 3Rewriting the rules: Succeeding in the new retail banking landscape
# reducing branches and growing digital sales at a
# more gradual rate. In many Asian, African, and
#
# Latin American countries, branch reduction is not
#
# so apparent—only because retail banks in these
#
# markets leapfrogged branch distribution to go
#
# directly to digital sales.
# The rate of branch reduction is often tied to
# customer willingness to purchase banking
#
# products online or on mobile devices. Eighty to
# ninety percent of banking customers in the
# Nordics, for example, are open to digital product
#
# purchases for most financial products, compared
#
# to 50 to 60 percent in North America and
#
# Southern Europe (
# Exhibit 3, page 5). While customer willingness to purchase products via
#
# digital channels varies, however, the common
#
# thread is that in all markets this readiness is far
#
# ahead of actual digital sales and will require banks
#
# to catch up to consumer needs and expectations.   0060206.0
# 402.0
# 4.0100916
# 0820040506072017
# 1112131415
# 100916
# 0820040506072017
# 1112131415
# Peak
# branches
# -15%
# Peak
# branches
# -15%
# 4000.40200.2
# 0.60.8
# 1.0
# Exhibit 1
# Top 25
# US banks
# Top 5
# US banks
# Branches
# Thousands
# Branches
# Thousands
# Deposits
# 1$ trillion
# Deposits
# $ trillion
# 210%
# increase in
#
# deposits
#  since 2008
# 257%
# increase in
#
# deposits
#  since 2008
# 15% decline
# in branches
#  since 2008
#
# peak15% decline
# in branches
#  since 2008
#
# peakDepositsBranches1 Deposits r
# epresent transaction deposits only.
# Source: SNL; McKinsey analysis
# The correlation between branch scale and deposit growth has
# weakened for US retail banks.
#
# --
# Summarized Text Length: 427
# branch reduction is often tied to customer willingness to purchase banking products online or on mobile devices . 80 to ninety percent of banking customers in the Nordics are open to digital product purchases for most financial products, compared to 50 to 60 percent in North America and southern Europe . in all markets this readiness is far ahead of actual digital sales and will require banks to catch up to consumer needs .
#
# ---- Page No. 5----
# Original Text Length: 1779
# Original Text: 4Rewriting the rules: Succeeding in the new retail banking landscape
# Within any specific market, of course, there are
# banks that have acted swiftly to adopt digital and
# remote as their main channel for interactions, and
#
# those that have lagged behind (Exhibit 4, page 6). One UK bank makes more than 50 percent of sales
#
# through digital channels, well ahead of market peers.
#
# Even in the historically branch-dependent small
# business segment, a range of banks and fintechs are
#
# finding that remote value propositions delivered
#
# digitally (e.g., remote relationship managers at Nordic
#
# banks) are attractive to small businesses.
# Banks that are ahead of the curve in terms of
# capitalizing on this shift are pulling away from the
#
# pack and have taken decisive actions on several
# fronts:
#   Set a bold aspiration for sales/service channel
# mix. Banks must do more than react to shifts
# in consumer preferences—they need to set
#
# aspirational targets for sales and service
# across channels. Some customers will self-
#
# select into digital channels, but banks can do 2016
# 0210
# 082000
# 400
# 04500
# 700
# 0612
# 800
# 9001,000
# 14600
# 200
# 0100
# 300
# UKCanada
# Finland
# Portugal
# SpainGermany
# Netherlands
# Italy
# Sweden
# DenmarkGreece
# USBank branches
# per million people
# 1Branches
#
# per million
#
# people2Peak-to-
#
# trough
#
# reduction
#  625
# Spain38%
#  494Portugal27%
#  486
# Italy16%
#  358Germany37%
#  306
# US17%
# 161
# Canada11%
#  213
# Greece42%
#  196
# Denmark56%
#  192
# Finland45%
#  183
# Sweden22%
#  153
# UK37%
# Netherlands 9971%
# Exhibit 2
# 1 Represents bank branch density per million people in the country.
# 2 Based on 2016 or latest year available.
# Source: McKinsey World Banking Intelligence database; McKinsey analysis
# The number of branches per million people is declining in North
# America, the UK, and Europe.
#
# --
# Summarized Text Length: 433
# one UK bank makes more than 50 percent of sales through digital channels . a range of banks and fintechs are finding that remote value propositions delivered digitally are attractive to small businesses . banks must do more than react to shifts in consumer preferences, they need to set aspirational targets for sales/service channel mix . the number of branches per million people is declining in North America, the UK, and Europe .
#
# ---- Page No. 6----
# Original Text Length: 1683
# Original Text: 5Rewriting the rules: Succeeding in the new retail banking landscape
# more to encourage less motivated customers
# to make the shift. Banks in markets like the
# Nordics and UK have reduced the number of
#
# customers using branches by up to 60
# percent by focusing on how to serve the
#
# heaviest branch users effectively through
#
# other channels.    Use advanced analytics to reshape the physical footprint. Optimizing the branch network requires a deep understanding of consumer
# preferences in every micro-market, and of the
# economics of making changes at the branch
# level. Leading institutions are using
#
# combinatorial optimization algorithms to
# optimize the net present value (NPV) of the
#
# network based on granular customer data on
# characteristics such as digital propensity,
#
# willingness to travel, needs based on
# transaction patterns and branch usage, and the
#
# size and space/format of branches. A European
#
# bank recently used this
# approach to
# identify 25 Willingness to purchase a digital product
# 1Percent of customers
# Purchases of products digitally
# 2Percent of customers
# 49565656606165718386UKEastern Europe
# Canada
# Italy
# USSpainGermany
# France
#
# Sweden
# Netherlands
# 12131311192414143237Exhibit 3
# 1 Represents customers that would be interested in purchasing their core banking product (e.g., checking account) digitally — vi
# a internet, tablet or mobile.
# 2 Percentage of customers that acquired their core banking product (e.g., checking account) digitally—from among customers that
# acquired a new product in the last 2 years.
# Source: McKinsey Consumer Multichannel Survey (n=12,000)
# Northern European banking customers lead the way in terms digital
# preferences.
#
# --
# Summarized Text Length: 560
# banks in markets like the Nordics and the UK have reduced the number of customers using branches by up to 60 percent . use advanced analytics to reshape the physical footprint . optimizing the branch network requires a deep understanding of consumer preferences in every micro-market, and of the economics of making changes at the branch level . leading institutions are using combinatorial optimization algorithms to optimize the net present value (NPV) of the network based on granular customer data on characteristics such as digital propensity, willingness
#
# ---- Page No. 7----
# Original Text Length: 1847
# Original Text: 6Rewriting the rules: Succeeding in the new retail banking landscape
# percent of branches that could be closed, and
# 35 percent of FTEs that could be redeployed.
#   Develop cutting-edge digital sales capabilities. Achieving meaningfully higher levels of digital sales requires a sophisticated approach to
#
# digital marketing and an understanding of how
# to optimize each stage of the funnel. Most
# consumers already seek information on
#
# financial products on digital channels (e.g.,
#
# bank websites, price comparison sites), but few institutions are highly effective at
# converting these inquiries into digital sales.
# Leading banks use first- and third-party data
#
# (e.g., geospatial, browsing behavior), a robust
#
# marketing technology stack (360-degree view
#
# of customer, omnichannel campaigns), and an
#
# agile operating model (e.g., cross-functional
#
# marketing war rooms). With these elements in
#
# place, progress can be rapid; a North
#
# American institution tripled annual online
# product sales in 12 months.
# Nordics
# Latin America
# Poland
# Average
# Digital customer activity
# June 2018
# Digital sales penetration
# July 2017 – June 2018
# Market
# highest
# 1observed
# Market
# lowest
# 1observed
# Activity
# 2: 57pp
# Sales3: 48ppSingapore
# Activity
# 2: 31pp
# Sales3: 47pp
# United Kingdom
# Activity
# 2: 22pp
# Sales3: 45ppUnited States
# Activity
# 2: 37pp
# Sales3: 41pp
# Australia/
# New Zealand
# Activity
# 2: 25pp
# Sales3: 30pp
# Italy
# Exhibit 4
# Note: For Latin America, Italy, and the Nordics, only average shown.
# 1 Lowest/highest observed for each metric in given market - not necessarily the same bank
# 2 Activity = difference between highest and lowest observed digital customer activity
# 3 Sales = difference between highest and lowest observed digital sales penetration
# Source: McKinsey
# In most markets, there are wide gaps between banks in terms of
# digital performance.
#
# --
# Summarized Text Length: 349
# leading banks use first- and third-party data (e.g., geospatial, browsing behavior), a robust marketing technology stack (360-degree view of customer, omnichannel campaigns), and an agile operating model . a north american institution tripled annual online product sales in 12 months . for Latin America, Italy, and the Nordics, only average shown .
#
# ---- Page No. 8----
# Original Text Length: 3765
# Original Text: 7Rewriting the rules: Succeeding in the new retail banking landscape
# 2. Customer experience is beginning to gener-
# ate meaningful separation in growth
# Across all retail businesses—including banks—
#
# customers now expect interactions to be simple,
# intuitive, and seamlessly connected across physical
#
# and digital touchpoints.  Banks are investing in meeting these expectations
# but have struggled to keep pace—focusing on the
# less-than-lofty goal of making the experience “less
# bad” for customers, rather than “outstanding.”
# Many banks are hampered by legacy IT
#
# infrastructures and siloed data. As a result, few
#
# banks are true leaders in terms of customer
#
# experience. Even for leading institutions, typically
# only one-half to two-thirds of customers rate their
#
# experience as excellent. This holds true across
#
# product categories, including those such as cards
#
# and deposits that have higher digital adoption rates.  The impact of this less-than-stellar performance is measurable. For example, McKinsey analysis
# shows that in the US, top-quartile banks in terms
# of experience have had meaningfully higher
# deposit growth over the past three years (
# Exhibit 5, page 8). Simply being good does not move the
# needle; customer impact really shows when banks
#
# offer outstanding experiences. The few
#
# “experience leaders” emerging in retail banking are
#
# generating higher growth than their peers by
#
# attracting new customers and deepening
# relationships with their existing customer base.
#
# Highly satisfied customers are two-and-a-half
#
# times more likely to open new accounts/products
#
# with their existing bank than those who are merely
#
# satisfied; they are also less price sensitive and
#
# generate positive word of mouth.
# These experience leaders are adopting tactics
# pioneered by digital-native companies in other
#
# sectors such as ecommerce, travel, and
# entertainment: setting a “north star” based on proven markers of differentiated experience (e.g.,
#
# UX design, carrying context across channels),
#
# redesigning journeys that matter most for digital-
#
# first customers and not just digital-only
# customers, and establishing integrated real-time
#
# measurement that cuts across products,
#
# channels, and employees. These banks know that
# customer experience is not just about the front-
#
# end look and feel, but that it requires discipline,
#
# focus, and investment in the following actions:    Focus on the journeys and sub-journeys that matter: The relative contribution of sub-
# journeys (e.g.,
# app downloading; activating account) in determining overall customer experience varies considerably. In fact, ten to
#
# fifteen sub-journeys have the biggest
#
# customer satisfaction impact for most
# products and should thus be the first priority.
#
# For instance, when opening a new deposit
# account, the researching options sub-journey
# has eight times the impact on customer
# satisfaction than other account-opening sub-
# journeys, on average (
# Exhibit 6, page 9). For banks, the key is to prioritize these high-
# impact sub-journeys and systematically
#
# redesign them from scratch—a process that
#
# can take about three to four months and
#
# result in at least a 15 to 20 percent lift in
#
# customer satisfaction.   Change the way you engage with customers. Experience leaders understand that digitization is not just about creating a cutting-edge online
#
# and mobile experience, and that satisfaction is
# shaped by customer experience across
#
# channels.1 The experience should be seamless, especially on journeys that are more
#
# likely to take place over multiple channels,
# such as new account opening, financial 1  Walter Rizzi and Zubin Taraporevala, “The balancing act: Omnichannel excellence in retail banking,” McKinsey.com, January 2019.
#
# --
# Summarized Text Length: 447
# customers expect interactions to be simple, intuitive, and seamlessly connected across physical and digital touchpoints . many banks are hampered by legacy IT infrastructures and siloed data . ten to fifteen sub-journeys have the biggest customer satisfaction impact for most products and should therefore be the first priority . the experience should be seamless, especially on journeys that are more likely to take place over multiple channels .
#
# ---- Page No. 9----
# Original Text Length: 2023
# Original Text: 8Rewriting the rules: Succeeding in the new retail banking landscape
# advice, or issue resolution. One wealth manager equipped its front-line relationship
#
# managers with robo-advice algorithms that are
#
# in sync with what customers see on the self-
# directed channel—and provided the RMs with
#
# daily and weekly next-best-action
# recommendations to nudge their clients.
#
# Banks need to deploy these tools broadly and
#
# empower their front-line staff to play a more
#
# consultative role that blends human and digital
#
# recommendations. They will also need to
#
# revisit how these employees are incentivized,
#
# shifting to a longer-term view of relationships
#
# and profitability rather than just product sales.
#   Translate data into personalized products
# and real-time offers. The amount of data available on individual customers or
# prospects has exploded in recent years. The
#
# challenge is to convert this data into
# actionable nudges and highly relevant offers
#
# for customers that are delivered at the right
#
# moment. Credit card companies have long
#
# offered discounts on specific spending
#
# categories or with specific retailers. Today,
#
# however, they can improve loyalty and share
#
# of spending by providing location-specific
#
# offers right when a customer enters a coffee
#
# shop, movie theater, or car dealership. South
# Real differences in customer satisfaction
# 1CSAT (Percent of customers rating 9 or 10)
#  Leaders in customer experience are
# growing faster
# Deposit CAGR (2014-17)
# 65554939-26
# 5.93.2
# 46%
# Top
# quartile
# CSAT
# Bottom
# quartile
# CSAT
# Bottom
# quartile
# 3rdquartile
# 2nd
# quartile
# Top
# quartile
# Exhibit 5
# 1 Percentage of respondents that selected a 9 or 10 on a 10-point customer satisfaction scale. Question: “We would like to
# understand your experience with [product] with [Bank]. Overall, how satised or dissatised are you with [product] with [Bank]?
# ”Source: McKinsey 2018 Retail Banking Customer Experience Benchmark Survey.
# US retail banks with better customer experience are growing deposits
# faster.
#
# --
# Summarized Text Length: 390
# the amount of data available on individual customers or prospects has exploded in recent years . banks need to deploy these tools broadly and empower front-line staff to play a more consultative role that blends human and digital recommendations . the challenge is to convert this data into actionable nudges and highly relevant offers for customers that are delivered at the right moment .
#
# ---- Page No. 10----
# Original Text Length: 1488
# Original Text: 9Rewriting the rules: Succeeding in the new retail banking landscape
# Africa’s Discovery, as an example, is
# launching a bank with product features that
#
# are informed by behavioral science and
#
# incentive design research (e.g., dynamic
#
# interest rates for savings and credit products
#
# that are tied to healthy financial behavior).
# 3. Productivity gains and returns to scale
#
# are back
# Larger retail banks have historically tended to be
#
# more efficient than their smaller competitors,
#
# benefiting from distribution network effects and
#
# the shared overhead for IT, infrastructure, and
#
# other shared services. Our analysis of over 3,000
# 515
# 01020253040
# 3545
# 5050055606570Importance
# Relative importance %
# 3Researching options
# Deposit sub-journeys
# 1Downloading the app
# Activating the account
# Learning about account features
# Completing the application
# Performance
# Journey SAT (top 2 boxes)
# 2Exhibit 6
# 1 Deposit example journeys shown; trend also holds true for credit card and mortgage account-opening sub-journeys.
# 2 Customer satisfaction with individual sub-journeys. Represents percentage of customers that rated the sub-journey 9 or 10 (on
# 10-point scale).
# 3 Relative importance is the amount that any individual sub-journey impacts the total journey score; calculated using a variance
#  decomposition approach.
# Source: McKinsey 2018 North American Retail Banking Journey Benchmarks
# Banks should prioritize the sub-journeys the have the most impact on
# customer experience.
#
# --
# Summarized Text Length: 342
# productivity gains and returns to scale are back Larger retail banks have historically tended to be more efficient than their smaller competitors . our analysis of over 3,000 515 01020253040 3545 5050055606570Importance Relative importance % 3Researching options Deposit sub-journeys 1Downloading the app Performance Journey SAT (top 2 boxes)
#
# ---- Page No. 11----
# Original Text Length: 1983
# Original Text: 10Rewriting the rules: Succeeding in the new retail banking landscape
# banks around the globe shows that while there is
# variation across countries, larger institutions tend
#
# to be more efficient both in terms of cost-to-asset
#
# (Exhibit 7) and cost-to-income ratios. However,
# beyond a certain point, even larger institutions
# struggle to eke out efficiencies or realize benefits
#
# from scale. For example, even after several years
#
# of cost-cutting after the most recent financial
#
# crisis, large US retail banks have not made
#
# material improvements in productivity over the
#
# past decade (Exhibit 8).   We expect this paradigm to change over the next
# few years, as structural improvements in efficiency
#
# ratios and increasing returns to scale enable some
#
# large banks to become even more efficient. The
#
# reason is two-fold: first, advances in technologies
#
# such as robotic process automation, machine
#
# learning, and cognitive artificial intelligence—many
#
# of which are now mainstream and commercially
#
# viable—are unleashing a new wave of productivity
#
# improvements for financial institutions. Deployed
#
# effectively, these tools can reduce costs by as
# Country examples
# 32015-17 C/A, bps
# Lowest quintile
#  Quintile 3
# Quintile 2
# Quintile 4
# Top quintile
# Top 3 banks
# 349296
# 277
# 320307306
# -15%
# 11499
# 113948786
# -24%
# 184121111959295
# -49%
# 390316247150219184
# -53%
# ChinaIndiaJapan
# US-1-3-6-5
# 0-4-20
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# Average cost to assets
# 2015-2017 C/A, bps
# LowHigh
# Market share
# Log (Market share)
# 225%
# 5%1%Exhibit 7
# Linear regression
# 1Y = 50bps - 50x
# R2 = 8.2%
#
# P-value: 2x10
# -16
#   1 Linear regression based on sample of ~3000 banks (all countries included with a sample size larger than 30).
# 2 Market share dened as bank’s asset size divided by total assets of banks from the specic country.
# 3 Quintiles based on market share.
# Source: S&P Global Market Intelligence; McKinsey Panorama
# The efÞciency advantage for large retail banks holds true on a global
# level.
#
# --
# Summarized Text Length: 459
# efciency advantage for large retail banks holds true on a global level . but even after several years of cost-cutting after the most recent financial crisis, large US retail banks have not made material improvements in productivity over the past decade . the reason is two-fold: first, advances in technologies such as robotic process automation, machine learning, and cognitive artificial intelligence are unleashing a new wave of productivity improvements .
#
# ---- Page No. 12----
# Original Text Length: 1441
# Original Text: 11Rewriting the rules: Succeeding in the new retail banking landscape
# much as 30 to 40 percent in customer-facing,
# middle-, and back-office activities, and
#
# fundamentally change how work is done.
# Dramatic change has already taken place in
#
# banking sectors such as capital markets, where
#
# algorithmic trading and automation are radically
#
# changing the talent profile and making a
#
# significant portion of existing jobs redundant.
# The second factor leading to a wave of productivity improvement in retail banking is the
#
# shift from physical to digital channels for
# customer acquisition. Banks with scale—and skills in leveraging that advantage—will achieve
# customer acquisition costs of up to two to three
#
# times lower than their smaller peers. Their
# outsized volumes of customer data will lead to
# better targeting and funnel conversion. As
# investments are shifted toward digital channels,
#
# the productivity gap between large and small
#
# banks will widen (Exhibit 9).  This dynamic has played out in more digitally
# mature industries, with firms like Amazon and
# Exhibit 8
# 1 Top 25 US banks by deposits in transaction accounts.
# Source: SNL; McKinsey analysis
# 705512092000
# 754016450650156065138002010307
# 0414
# 05082017
# 1011Cost/income ratio
# %Evolution of cost/income ratio for leading banks
# 1Lower
# quartile
# Median
# Upper
# quartile
# Most large US retail banks have struggled to improve productivity
# beyond a narrow efÞciency band.
#
# --
# Summarized Text Length: 379
# a wave of productivity improvement in retail banking is the shift from physical to digital channels for customer acquisition . this dynamic has played out in more digitally mature industries, with firms like amazon and Exhibit 8 1 Top 25 US banks by deposits in transaction accounts . a large US retail banks have struggled to improve productivity beyond a narrow efciency band .
#
# ---- Page No. 13----
# Original Text Length: 1993
# Original Text: 12Rewriting the rules: Succeeding in the new retail banking landscape
# Priceline acquiring customers at a significantly lower cost than competitors. As in these
# industries, eventually a limited number of dominant
# banks will emerge, squeezing out undifferentiated
#
# mid-sized and smaller banks. There are early signs
#
# of this trend: undifferentiated smaller community
#
# banks in the US have lost a significant share of
#
# deposits over the last two to three years, while the
#
# three largest banks have gained share. Of course,
#
# scale is not everything. Banks that succeed in this
# new wave of productivity will also have taken the
#
# following actions:    Use cutting-edge technology to automate: Over the next few years, banks will increase their use
# of technologies such as natural language
# processing and artificial intelligence to automate
#
# customer-facing interactions and complex
#
# internal tasks. Already, legal and compliance
#
# departments are automating the extraction of
#
# data from documents and using algorithms to
#
# triage suspicious patterns for manual review.
#
# One leading global institution recently revamped
#
# its customer-care process with a raft of new
#
# technologies to identify potential FTE reductions
# Cost/income ratio
# %101001,000
# 25-30%
# 50-55%
# 70-75%
# Bank size
#
# $ billion assets
# Current cost curve
# Future cost curve
# 100%
# Exhibit 9
# Greater returns to scale,
#  driven by ability to leverage
# investments in customer analytics and experience
#
# without needing to scale the physical presence
# Structurally lower cost across the curve
# , driven by adoption of technologies like
#
# machine learning, artielligence,
#
# robotic process automation
# Lower cost of starting up
# , driven by
# open banking architecture (e.g.,
#
# API-enabled “bank in a box”) and
#
# cloud hosting
#  Source: SNL; S&P Market Intelligence; McKinsey analysis
# Over the next 5 years, we expect the industry cost curve to shift
# fundamentally downward, with greater returns to scale for larger
#
# institutions.
#
# --
# Summarized Text Length: 518
# undifferentiated small community banks in the us have lost a significant share of deposits over the last two to three years . the three largest banks have gained share . over the next few years, banks will increase their use of technologies such as natural language processing and artificial intelligence to automate customer-facing interactions and complex internal tasks . a leading global institution recently revamped its customer-care process with a raft of new technologies to identify potential FTE reductions .
#
# ---- Page No. 14----
# Original Text Length: 3667
# Original Text: 13Rewriting the rules: Succeeding in the new retail banking landscape
# of more than 30 percent, and a North American
# bank used automation technologies to identify
# efficiency improvements of 20 percent in its
#
# finance function.
#   Build and reinforce the brand: With rising
# digital sales consumers have more choice
# than ever in selecting a financial services
# provider. However, our research shows that
#
# across most categories consumers actively
#
# consider only two to three products before
#
# deciding on a purchase. So it remains as
#
# important as ever for a bank to be part of the
# initial consideration set. Brands with superior
# awareness and recognition are not only more
#
# likely to be part of the initial consideration set
# but also achieve higher conversion rates than
# lesser-known brands when they are
#
# considered. A leading credit card provider in a
#
# major European market that invested heavily
#
# in brand awareness is now twice as likely to
#
# be actively considered—by 17 percent of
#
# consumers versus 7 to 10 percent for other
#
# brands—and experiences 50 percent higher
#
# conversion when considered compared to
#
# lesser-known brands.
# 2 The returns enjoyed by
# banks with superior recognition—in the form
#
# of lower acquisition costs—reinforce the
#
# benefits of scale and will be an advantage
# over time for larger institutions that can invest
# heavily in building and reinforcing their brand.
# 4. The unbundling and “rebundling” of
#
# retail banking
# The tight one-on-one retail banking relationships
#
# of old are unbundling. Forty percent of US
#
# households today hold a deposit account with
# more than one institution. It is common to have a
#
# mortgage with one bank, an unsecured loan with
# a different lender, and separate deposit and
# investment accounts. The banking relationship is
#
# fragmenting even faster in countries with higher
# digital adoption, such as the Netherlands and the
# UK, where the percentage of customers that use
#
# more than two providers has increased by 20
#
# percent over the past five years.
# This decline of customer loyalty provides a
# perfect context for firms seeking to enter banking
# in a selective way—focusing on the most
# profitable segments. Some attackers have
#
# demonstrated that despite incumbent banks’
# access to much more customer data, they can
#
# compete effectively on customer experience
#
# coupled with aggressive pricing to gain share.
#
# New entrants in financial services typically begin
# by focusing on a niche—making either a product
#
# or segment-focused play. For example,
#
# Wealthfront and Personal Capital in the US began
#
# with a sharp focus on mass affluent customers—
#
# providing robo advice aligned with financial goals
#
# at far less cost than traditional financial advisors.
# SoFi focused first on recent graduates from elite
#
# colleges, using student loan refi as a hook
#
# product. Their ambition, however, is to own the
#
# full banking relationship of this segment over
#
# time—providing cards, mortgage products, and
#
# broader banking services—although it remains to
#
# be seen how feasible this will prove in practice.
# The Open Banking movement, heralded by Europe’s second Payments Service Directive and
#
# the UK’s Open Banking Standards, has the
#
# potential to accelerate the unbundling of banking
# in the regions where it applies, leading to
#
# increasingly intense competition over the next few
#
# years.3 The requirement for banks to share data
# and provide access to consumer and small
# 2  January 2018 McKinsey research on 8,000 UK credit card applicants.
# 3Alessio Botta, Nunzio Digiacomo, Reinhard Höll, and Liz Oakes, “PSD2: Taking advantage of open-banking disruption,”
#
# --
# Summarized Text Length: 473
# a leading credit card provider in a major european market is twice as likely to be actively considered . the returns enjoyed by banks with superior recognition will be an advantage over time for larger institutions that can invest heavily in building and reinforcing their brand . some attackers have demonstrated that despite incumbent banks’ access to more customer data, they can compete effectively on customer experience coupled with aggressive pricing to gain share .
#
# ---- Page No. 15----
# Original Text Length: 3968
# Original Text: 14Rewriting the rules: Succeeding in the new retail banking landscape
# business accounts through a common framework
# of APIs is likely to fuel a wave of innovation and
# level the playing field for fintechs and technology
# providers seeking entry through payments or
#
# consumer financing. Recent McKinsey research
#
# shows that consumers are most interested in
#
# marketplace concepts that simplify comparisons
# and make it easier to switch between providers
#
# based on their needs and preferences.
# The trend toward unbundling in financial services is
# well under way, but where it will lead is still an open
#
# question. In industries such as music, television,
# ecommerce, and transportation, digital distribution
#
# led to unbundling that destroyed value for
#
# incumbents in the short term; over time, consumers
# tend to converge on a single provider—often an
#
# attacker. In this context, firms that effectively
#
# orchestrate platform or ecosystem environments
#
# tend to eventually emerge as winners.  The history of the music industry over the last 20 years provides a possible model for how things
#
# will go in banking (Exhibit 10). Until the 1990s, music distribution was dominated by stores
#
# selling tracks that record companies “bundled”
#
# onto albums. In the early 2000s, digital
# distribution, especially via iTunes, radically
#
# reduced distribution costs. Consumers could now
#
# “unbundle” albums by purchasing individual
#
# tracks online; not surprisingly, many record stores
#
# went out of business. Over the past few years,
# however, we have seen a “rebundling” in the form
#
# of the streaming playlist. Streaming services are
#
# now the dominant distribution channel, with a few
# large players such as Spotify and Apple emerging
# as winners. The success of these platforms is
# based on their ability to create highly
#
# personalized bundles based on consumer needs
# and preferences, and a superior interface without
#
# the friction of purchasing tracks individually.
#
# Leaders have created significant value for
#
# consumers by using customer data and insights to deliver a superior experience, rather than by manufacturing the underlying product.
# If we apply this scenario to banking, winning firms will be those that leverage superior access to
# customer data to provide truly differentiated and
#
# cutting-edge experiences—potentially extending
# beyond financial products and services. To do
#
# this effectively, banks will need to retain privileged
#
# access to information about consumers’ sources
#
# and use of funds, especially through payments
#
# and transaction activity. Banks that rebundle
#
# effectively will use this data to deliver compelling
#
# and integrated experiences that provide seamless
#
# funding, investment, payments, and money
# movement capabilities. The bottom line is that in
# order to reverse the unbundling of financial
#
# services, banks need to make it worthwhile for
# consumers to have a relationship with one
#
# institution; they need to deliver not only simplicity
# and convenience, but also superior value. Only a
# few banks in each market are likely to be able to
#
# succeed with this strategy.
# Already, large technology firms such as Amazon
# are extending into parts of the financial services
#
# value chain, starting with areas where they have a
#
# data advantage such as payments, short-term
# financing for purchases, and working capital
#
# loans for merchants on their platform. To counter
#
# the unbundling of their most profitable products,
#
# banks need to develop capabilities that few
# currently possess, and follow the lead of
#
# successful technology platforms:    Retain superior access to data on transactions and financial behavior: As vast amounts of data are captured by tech firms on
#
# consumers’ behavior and preferences, one of
#
# the last bastions of valuable information is
# data on transactions and financial behavior. To
#
# retain unparalleled access to this data, banks
#
# will need to continue to own the transaction
# --
# Summarized Text Length: 390
# the trend toward unbundling in financial services is well under way, but where it will lead is still an open question . the history of the music industry over the last 20 years provides a possible model for how things will go in banking . banks need to retain privileged access to information about consumers’ sources and use of funds, especially through payments and transaction activity .
#
# ---- Page No. 16----
# Original Text Length: 1723
# Original Text: 15Rewriting the rules: Succeeding in the new retail banking landscape
# layer, giving them a full view of inbound and
# outbound activity, to form a complete picture
#
# of consumer balance sheets. Historically, this
#
# required a bank to be a customer’s primary
#
# checking account provider; over time, we
#
# expect that institutions could do this without
# necessarily owning the checking account
# relationship. In some cases, payments or
#
# transaction providers could see a significant
#
# share of customers’ spend volume. Financial
#
# aggregators that sit on top of a suite of
#
# products and services that are manufactured
# by others may also be in a position to capture
# a broad spectrum of customer activity and
#
# use it to build an analytics advantage.    Leverage insights to develop innovative products and features: The traditional suite of products that financial institutions offer has
#
# remained largely unchanged over the past few
#
# decades—e.g., checking accounts, lending,
# cards/payments, wealth management—and is
#
# often structurally hard to change given how
#
# banks are organized. More nimble firms will be
# Market
# concentration
# Industry
#
# maturity
# 1990s2000s2010s
# Exhibit 10
# Streaming services
#
# emerge, focusing on
#
# customer experience
#
# and using analytics to
# “rebundle” tracks into
# playlists that are
#
# tailored to individuals
# Fully unbundled music
# delivery, characterized
#
# by individuals
#
# purchasing individual
#
# tracks through digital
#
# channels and burning
#
# bespoke CDs
# Music delivered as
# “albums,” pre-bundled
# by a small number of
#
# record labels onto CDs
#  Source: McKinsey analysis
# The unbundling and rebundling in the music industry may provide a
# possible model for retail banking distribution.
#
# --
# Summarized Text Length: 429
# financial aggregators that sit on top of a suite of products and services may also be in a position to capture a broad spectrum of customer activity and use it to build an analytics advantage . the traditional suite of services that financial institutions offer has remained largely unchanged over the past few decades—e.g., checking accounts, lending, cards/payments, wealth management—and is often structurally hard to change .
#
# ---- Page No. 17----
# Original Text Length: 1772
# Original Text: 16Rewriting the rules: Succeeding in the new retail banking landscape
# able to leverage insights to create unique
# offerings—for example, cash in a checking
#
# account could automatically be optimized for
# return based on financial behaviors and spend
#
# patterns without needing to ring-fence and
#
# transfer it to a separate high-yield deposit or
# brokerage account. Or, when a customer
#
# takes a short-term unsecured loan the rate
#
# might be optimized based on the steadiness
# of their income stream and savings
#
# accumulated each month, and they could
# collateralize against balances in other
# accounts with the bank.   Extend beyond purely financial services and
# products over time: There are a couple of
# clear benefits that financial institutions are
#
# likely to have relative to ecosystems being
#
# created by large tech firms. Superior access
#
# to financial information enables them to create
#
# faster and more precise offers for big-ticket
#
# products that have financing needs associated
#
# with them (e.g., homes or cars). For these
# types of products, banks could be well-
#
# positioned to own the full customer journey,
# including the browsing experience and the
# transaction. One Northern European bank has
#
# developed a mobile app that integrates house
# searches, booking viewings, budgeting,
#
# transactions, and help with setting up a new
# home (e.g., utilities, appliances, and
# renovation).
# 4 In the US, Capital One’s Auto
# Navigator facilitates a seamless search
#
# experience for car buyers and can provide
#
# instant approval for financing before they visit
#
# a dealership. 4  Miklós Dietz, Reka Hamvai, Paul Jenkins, Miklos Radnai, and Michael Yee, “Deep insights, broad solutions: How banks can win in
# the vast housing ecosystem,” McKinsey.com, June 2018.
#
# --
# Summarized Text Length: 426
# one Northern European bank has developed a mobile app that integrates house searches, booking viewings, budgeting, transactions, and help with setting up a new home . capital One’s Auto Navigator facilitates a seamless search experience for car buyers and can provide instant approval for financing before they visit a dealership . a customer can take a short-term unsecured loan to a high-yield deposit or brokerage account .
# Your max_length is set to 300, but you input_length is only 48. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# ---- Page No. 18----
# Original Text Length: 2282
# Original Text: 17Rewriting the rules: Succeeding in the new retail banking landscape
# The path forward
# In the near term, competition in retail banking is
# likely to intensify, with only a few banks emerg-
#
# ing as winners. These banks will take bold steps
# now to establish a formidable position that fends
# off new entrants and smaller attackers. Retail
#
# banking leaders should consider and debate the
# following questions as they face the challenges
# of the coming years:  1.What is our strategy to increase customer
# growth over the next three to five years, not
#
# just protect existing share of wallet?
# 2.How bold can we be with our distribution
# plan, and will it be effective two to three years
#
# from now?
# 3.Are we on track to deliver a superior customer
# experience in the next 12 months? What ca-
# pabilities will differentiate us from the compe-
#
# tition?  4.How can we deploy new technologies to re-
# duce our cost structure? Are we building the
# infrastructure to capture and harness data so
# we can benefit from scale?
# 5.Do we need to reposition or reinforce our
# brand, or develop new attacker brands, to tap
# into new customer segments?  6.Are we prepared for the impact of Open Bank-
# ing and similar rules that pave the way for at-
# tackers and fintechs? What offensive and
#
# defensive moves do we need to make?  7.How do we position ourselves to rebundle
# products and services around customer
#
# needs? How should we design our platform
# and what partnerships should we pursue?   Our view is that retail banking is at an inflection
# point, and that the pace of change will accelerate
# significantly over the next three to five years. Suc-
#
# cess will require clarity in direction, and speed
#
# and agility in execution. Retail banks that capital-
# ize on current shifts in the market will emerge
#
# with a winning position in their core markets and
#
# begin to compete across borders.
# Vaibhav Gujral is a partner and Nick Malik is a senior partner, both in McKinsey’s New York office.
# Zubin Taraporevala is a senior partner in the London office.
#
# The authors would like to thank Ashwin Adarkar, Jacob Dahl, Filippo Delzi, Miklos Dietz, Dave Elzinga,
#
# Darius Imregun, Somesh Khanna, Marc Levesque, Alejandro Martinez, and Robert Schiff for their
# contributions to this article.
# --
# Summarized Text Length: 336
# retail banking leaders should consider and debate the following questions as they face the challenges of the coming years . the authors would like to thank Ashwin Adarkar, Jacob Dahl, Filippo Delzi, Miklos Dietz, Dave Elzinga, Darius Imregun, Somesh Khanna, Marc Levesque, Alejandro Martinez, and Robert Schiff for their contributions .
#
# ---- Page No. 19----
# Original Text Length: 133
# Original Text: Global Banking Practice  February 2019
# Copyright © McKinsey & Company
# www.mckinsey.com/industries/financial-services/our-insights
#
# --
# Summarized Text Length: 197
# global banking practice February 2019 Copyright  McKinsey & Company www.mckinsey.com/industries/financial-services/our-insights.html   Copyright: 'i'm not a banker, but i don't know what I'm doing'

# %% [markdown]
# # Use Google T5 Model

# %%
from transformers import TFAutoModelWithLMHead, AutoTokenizer
model = TFAutoModelWithLMHead.from_pretrained("t5-base")
tokenizer = AutoTokenizer.from_pretrained("t5-base")
# Out:
# FutureWarning: The class `TFAutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `TFAutoModelForCausalLM` for causal language models, `TFAutoModelForMaskedLM` for masked language models and `TFAutoModelForSeq2SeqLM` for encoder-decoder models. [modeling_tf_auto.py:533]
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at t5-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %%
# T5 uses a max_length of 512 so we cut the article to 512 tokens.
inputs = tokenizer.encode("summarize: " + document1, return_tensors="tf", max_length=512)
outputs = model.generate(inputs, max_length=250, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
# Decoding and printing summary

GT5_summary=tokenizer.decode(outputs[0], skip_special_tokens=True)
print(GT5_summary)
# Out:
# four shifts are reshaping the global retail banking landscape. banks need to fundamentally rethink what it takes to compete and win. banks are now competing on customer experience, with leaders growing faster.

# %%
summary_text_t5 = ''

for ids in outputs:
    summary_text_t5 += tokenizer.decode(ids, skip_special_tokens=True)

print("Original: " + document1)
print("\n\nSummarized T5:" + summary_text_t5)
# Out:
# Original: Succeeding in the new retail banking landscape Retail banks have long competed on distribution, realizing economies of scale through network effects and investments in brand and infrastructure. But even those scale economies had limits above a certain size. As a result, in most retail banking markets, a few large institutions, operating at similar efficiency ratios, dominate market share. Changes to the retail banking business model have mostly come in response to regulatory shifts, as opposed to a purposeful reimagining of what the winning bank of the future will look like. Retail banks have also not kept pace with the improvements in customer experience seen in other consumer industries. Few banks stand out for innovation in customer interaction models or branch formats. Marketing investments have traditionally focused on brand building and increasing loyalty: a reputable brand stood for trust and security and became a moat, providing protection against new entrants to the sector. Finally, most banks offer similar products, with limited innovation in features. Today, the moats that banks have built are more likely to restrict their own progress than protect them from attackers. Four shifts are reshaping the global retail banking landscape to the point where banks need to fundamentally rethink what it takes to compete and win. This should be an urgent priority for banks. The pace of change will likely accelerate, with a select set of large-scale winners emerging in the next three to five years that will gain share in their core markets and begin to compete across borders, leaving many sub-scale institutions scrambling for relevance. Rewriting the rules: Succeeding in the new retail banking landscape 2Rewriting the rules: Succeeding in the new retail banking landscape Four shifts are reshaping retail banking Four secular shifts are changing the way retail banks will compete in the coming years:    The traditional distribution-led growth formula is losing relevance, with a breakdown in the relationship between branch footprint and growth. Banks are now competing on customer experience, with leaders growing faster than their competitors.    Scale economics are back—banks that excel at deploying new technologies (e.g., automation and machine learning) and those with a more digital-centric channel mix will have a structural cost advantage.    The retail banking relationship is getting unbundled along product lines, fueled by digitization and, increasingly, by regulation— and the biggest profit pools are under attack. A few banks will be able to temper and reverse this trend, using superior data and analytics capabilities to build deeper and broader relationships with their customers. In the near term, these shifts will combine to intensify competition as new entrants and incumbents seek to push past traditional boundaries. More than 100 digital attacker banks have launched in the last few years globally— including N26, Monzo and Revolut in Europe; WeBank, Digibank, Jenius in Asia; SoFi, Marcus, Moven in the US; Nubank in South America— while many incumbents have launched or are considering launching digital-first models.  Over the next three to five years, we expect a few players to emerge from this competitive scrum to gain dominant share in their core markets and possibly beyond. These firms will have taken bold and decisive actions to capitalize on the shifts that are reshaping the industry. In some cases, these winners will be incumbents that build on an already significant share; in others, they will be institutions newer to the banking industry, which use their agility, strategic aggressiveness, and sharp execution to attract customers.   1. The traditional distribution-led growth formula no longer applies Until the financial crisis in 2007, a retail bank’s total share of deposits was tightly linked to the size of its branch network. Even as internet use grew rapidly, customers still visited branches for account se ...
#
#
# Summarized T5:four shifts are reshaping the global retail banking landscape. banks need to fundamentally rethink what it takes to compete and win. banks are now competing on customer experience, with leaders growing faster.

# %%
page_count = 1

'''

for page in pdf.pages:
    text = page.extractText()
    
    #Config the HF Summarization pipeline
    summarized_text = summarizer(text, min_length=75, max_length=300)
  
    # Setting max_length of 512 for t5-so we cut the article to 512 tokens.
    chunked_input = tokenizer.encode("summarize: " + text, return_tensors="tf", max_length=512)
    summarized_output = model.generate(chunked_input, max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    
    
    # Print summarized text
    print("\n---- Page No. " + str(page_count) + "----")
    print ("Original Text Length: " + str(len(text)))
    print("Original Text: " + text)
    print ("--")
    print ("Summarized Text Length: " + str(len(summarized_output)))
    print(summarized_output)
    page_count += 1
    
'''
# Out:
# Your max_length is set to 300, but you input_length is only 44. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# ---- Page No. 1----
# Original Text Length: 166
# Original Text: Rewriting the rules: Succeeding in the
# new retail banking
#
# landscape  Authored by:
# Vaibhav Gujral
# Nick Malik
# Zubin Taraporevala
# Global Banking  February 2019
# --
# Summarized Text Length: 1
# [{'summary_text': 'rewriting the rules: Succeeding in the new retail banking landscape Authored by: Vaibhav Gujral Nick Malik Zubin Taraporevala Global Banking February 2019 . the rules are based on the rules of the retail banking industry . it is the first time the banking landscape has been rewritten .'}]
#
# ---- Page No. 2----
# Original Text Length: 1809
# Original Text: 1Rewriting the rules: Succeeding in the new retail banking landscape
# Retail banks have long competed on distribution, realizing economies of scale through network
#
# effects and investments in brand and
#
# infrastructure. But even those scale economies
#
# had limits above a certain size. As a result, in
#
# most retail banking markets, a few large
#
# institutions, operating at similar efficiency ratios,
#
# dominate market share. Changes to the retail
#
# banking business model have mostly come in
# response to regulatory shifts, as opposed to a
#
# purposeful reimagining of what the winning bank
#
# of the future will look like.
# Retail banks have also not kept pace with the improvements in customer experience seen in
#
# other consumer industries. Few banks stand out
# for innovation in customer interaction models or
# branch formats. Marketing investments have
# traditionally focused on brand building and increasing loyalty: a reputable brand stood for
# trust and security and became a moat, providing
#
# protection against new entrants to the sector.
#
# Finally, most banks offer similar products, with
#
# limited innovation in features.
# Today, the moats that banks have built are more
# likely to restrict their own progress than protect
#
# them from attackers. Four shifts are reshaping
#
# the global retail banking landscape to the point
#
# where banks need to fundamentally rethink what
#
# it takes to compete and win. This should be an
# urgent priority for banks. The pace of change will
# likely accelerate, with a select set of large-scale
# winners emerging in the next three to five years
#
# that will gain share in their core markets and
#
# begin to compete across borders, leaving many
#
# sub-scale institutions scrambling for relevance.
# Rewriting the rules: Succeeding in the new retail banking landscape
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'banks have long competed on distribution, realizing economies of scale through network effects and investments in brand and infrastructure . but even those scale economies had limits above a certain size . change to the retail banking business model has mostly come in response to regulatory shifts, as opposed to a purposeful reimagining of what the winning bank of the future will look like . few banks stand out for innovation in customer interaction models or branch formats .'}]
#
# ---- Page No. 3----
# Original Text Length: 3601
# Original Text: 2Rewriting the rules: Succeeding in the new retail banking landscape
# Four shifts are reshaping retail
# banking Four secular shifts are changing the way retail
# banks will compete in the coming years:    The traditional distribution-led growth
# formula is losing relevance, with a
# breakdown in the relationship between
#
# branch footprint and growth.
#   Banks are now competing on customer
# experience, with leaders growing faster than
# their competitors.    Scale economics are back—banks that excel
# at deploying new technologies (e.g., automation and machine learning) and those
#
# with a more digital-centric channel mix will
#
# have a structural cost advantage.    The retail banking relationship is getting
# unbundled along product lines, fueled by
# digitization and, increasingly, by regulation—
#
# and the biggest profit pools are under attack.
#
# A few banks will be able to temper and
# reverse this trend, using superior data and
#
# analytics capabilities to build deeper and
# broader relationships with their customers.
# In the near term, these shifts will combine to intensify competition as new entrants and
# incumbents seek to push past traditional
# boundaries. More than 100 digital attacker banks
#
# have launched in the last few years globally—
# including N26, Monzo and Revolut in Europe;
#
# WeBank, Digibank, Jenius in Asia; SoFi, Marcus,
#
# Moven in the US; Nubank in South America—
# while many incumbents have launched or are
#
# considering launching digital-first models.  Over the next three to five years, we expect a
# few players to emerge from this competitive
#
# scrum to gain dominant share in their core
#
# markets and possibly beyond. These firms will
# have taken bold and decisive actions to
# capitalize on the shifts that are reshaping the
# industry. In some cases, these winners will be
# incumbents that build on an already significant
#
# share; in others, they will be institutions newer to
#
# the banking industry, which use their agility,
#
# strategic aggressiveness, and sharp execution to
#
# attract customers.   1. The traditional distribution-led growth formula
#
# no longer applies Until the financial crisis in 2007, a retail bank’s
#
# total share of deposits was tightly linked to the
#
# size of its branch network. Even as internet use
#
# grew rapidly, customers still visited branches for
#
# account servicing and to learn about and
#
# purchase new products. The physical branch
#
# created a sense of security and trust. Banks with
#
# higher branch density benefited from a network
#
# effect—the more branches, the higher the
#
# likelihood of acquiring and retaining customers.
# Over the past decade, this relationship between
# deposit growth and branch density has
#
# weakened. Deposits at the 25 largest US retail
#
# banks have doubled over the past decade, while
# their combined branch footprint shrank by 15
# percent over the same period. This reverse
#
# correlation is even sharper for the top five US
#
# banks—while reducing branches by 15 percent,
#
# they increased deposits by 2.6 times (
# Exhibit 1). While there have been previous periods of
#
# branch contraction, they were clearly tied to
#
# economic downturns; this most recent wave of
#
# retrenchment commenced about a decade ago
#
# and has persisted through a period of robust
#
# economic growth.
# Retail banking branch networks are contracting
# across North America, the UK, and Europe
#
# (Exhibit 2, page 4), although the pace of change varies considerably between regions. Those that
#
# are ahead of the curve have reduced branches
#
# by as much as 71 percent (Netherlands). Banks
#
# in North America and Southern Europe are
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'the traditional distribution-led growth formula no longer applies Until the financial crisis in 2007, a retail bank’s total share of deposits was tightly linked to the size of its branch network . this reverse correlation is even sharper for the top five US banks—while reducing branches by 15 percent, they increased deposits by 2.6 times over the same period . the pace of change varies considerably between regions .'}]
#
# ---- Page No. 4----
# Original Text Length: 1602
# Original Text: 3Rewriting the rules: Succeeding in the new retail banking landscape
# reducing branches and growing digital sales at a
# more gradual rate. In many Asian, African, and
#
# Latin American countries, branch reduction is not
#
# so apparent—only because retail banks in these
#
# markets leapfrogged branch distribution to go
#
# directly to digital sales.
# The rate of branch reduction is often tied to
# customer willingness to purchase banking
#
# products online or on mobile devices. Eighty to
# ninety percent of banking customers in the
# Nordics, for example, are open to digital product
#
# purchases for most financial products, compared
#
# to 50 to 60 percent in North America and
#
# Southern Europe (
# Exhibit 3, page 5). While customer willingness to purchase products via
#
# digital channels varies, however, the common
#
# thread is that in all markets this readiness is far
#
# ahead of actual digital sales and will require banks
#
# to catch up to consumer needs and expectations.   0060206.0
# 402.0
# 4.0100916
# 0820040506072017
# 1112131415
# 100916
# 0820040506072017
# 1112131415
# Peak
# branches
# -15%
# Peak
# branches
# -15%
# 4000.40200.2
# 0.60.8
# 1.0
# Exhibit 1
# Top 25
# US banks
# Top 5
# US banks
# Branches
# Thousands
# Branches
# Thousands
# Deposits
# 1$ trillion
# Deposits
# $ trillion
# 210%
# increase in
#
# deposits
#  since 2008
# 257%
# increase in
#
# deposits
#  since 2008
# 15% decline
# in branches
#  since 2008
#
# peak15% decline
# in branches
#  since 2008
#
# peakDepositsBranches1 Deposits r
# epresent transaction deposits only.
# Source: SNL; McKinsey analysis
# The correlation between branch scale and deposit growth has
# weakened for US retail banks.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'branch reduction is often tied to customer willingness to purchase banking products online or on mobile devices . 80 to ninety percent of banking customers in the Nordics are open to digital product purchases for most financial products, compared to 50 to 60 percent in North America and southern Europe . in all markets this readiness is far ahead of actual digital sales and will require banks to catch up to consumer needs .'}]
#
# ---- Page No. 5----
# Original Text Length: 1779
# Original Text: 4Rewriting the rules: Succeeding in the new retail banking landscape
# Within any specific market, of course, there are
# banks that have acted swiftly to adopt digital and
# remote as their main channel for interactions, and
#
# those that have lagged behind (Exhibit 4, page 6). One UK bank makes more than 50 percent of sales
#
# through digital channels, well ahead of market peers.
#
# Even in the historically branch-dependent small
# business segment, a range of banks and fintechs are
#
# finding that remote value propositions delivered
#
# digitally (e.g., remote relationship managers at Nordic
#
# banks) are attractive to small businesses.
# Banks that are ahead of the curve in terms of
# capitalizing on this shift are pulling away from the
#
# pack and have taken decisive actions on several
# fronts:
#   Set a bold aspiration for sales/service channel
# mix. Banks must do more than react to shifts
# in consumer preferences—they need to set
#
# aspirational targets for sales and service
# across channels. Some customers will self-
#
# select into digital channels, but banks can do 2016
# 0210
# 082000
# 400
# 04500
# 700
# 0612
# 800
# 9001,000
# 14600
# 200
# 0100
# 300
# UKCanada
# Finland
# Portugal
# SpainGermany
# Netherlands
# Italy
# Sweden
# DenmarkGreece
# USBank branches
# per million people
# 1Branches
#
# per million
#
# people2Peak-to-
#
# trough
#
# reduction
#  625
# Spain38%
#  494Portugal27%
#  486
# Italy16%
#  358Germany37%
#  306
# US17%
# 161
# Canada11%
#  213
# Greece42%
#  196
# Denmark56%
#  192
# Finland45%
#  183
# Sweden22%
#  153
# UK37%
# Netherlands 9971%
# Exhibit 2
# 1 Represents bank branch density per million people in the country.
# 2 Based on 2016 or latest year available.
# Source: McKinsey World Banking Intelligence database; McKinsey analysis
# The number of branches per million people is declining in North
# America, the UK, and Europe.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'one UK bank makes more than 50 percent of sales through digital channels . a range of banks and fintechs are finding that remote value propositions delivered digitally are attractive to small businesses . banks must do more than react to shifts in consumer preferences, they need to set aspirational targets for sales/service channel mix . the number of branches per million people is declining in North America, the UK, and Europe .'}]
#
# ---- Page No. 6----
# Original Text Length: 1683
# Original Text: 5Rewriting the rules: Succeeding in the new retail banking landscape
# more to encourage less motivated customers
# to make the shift. Banks in markets like the
# Nordics and UK have reduced the number of
#
# customers using branches by up to 60
# percent by focusing on how to serve the
#
# heaviest branch users effectively through
#
# other channels.    Use advanced analytics to reshape the physical footprint. Optimizing the branch network requires a deep understanding of consumer
# preferences in every micro-market, and of the
# economics of making changes at the branch
# level. Leading institutions are using
#
# combinatorial optimization algorithms to
# optimize the net present value (NPV) of the
#
# network based on granular customer data on
# characteristics such as digital propensity,
#
# willingness to travel, needs based on
# transaction patterns and branch usage, and the
#
# size and space/format of branches. A European
#
# bank recently used this
# approach to
# identify 25 Willingness to purchase a digital product
# 1Percent of customers
# Purchases of products digitally
# 2Percent of customers
# 49565656606165718386UKEastern Europe
# Canada
# Italy
# USSpainGermany
# France
#
# Sweden
# Netherlands
# 12131311192414143237Exhibit 3
# 1 Represents customers that would be interested in purchasing their core banking product (e.g., checking account) digitally — vi
# a internet, tablet or mobile.
# 2 Percentage of customers that acquired their core banking product (e.g., checking account) digitally—from among customers that
# acquired a new product in the last 2 years.
# Source: McKinsey Consumer Multichannel Survey (n=12,000)
# Northern European banking customers lead the way in terms digital
# preferences.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'banks in markets like the Nordics and the UK have reduced the number of customers using branches by up to 60 percent . use advanced analytics to reshape the physical footprint . optimizing the branch network requires a deep understanding of consumer preferences in every micro-market, and of the economics of making changes at the branch level . leading institutions are using combinatorial optimization algorithms to optimize the net present value (NPV) of the network based on granular customer data on characteristics such as digital propensity, willingness'}]
#
# ---- Page No. 7----
# Original Text Length: 1847
# Original Text: 6Rewriting the rules: Succeeding in the new retail banking landscape
# percent of branches that could be closed, and
# 35 percent of FTEs that could be redeployed.
#   Develop cutting-edge digital sales capabilities. Achieving meaningfully higher levels of digital sales requires a sophisticated approach to
#
# digital marketing and an understanding of how
# to optimize each stage of the funnel. Most
# consumers already seek information on
#
# financial products on digital channels (e.g.,
#
# bank websites, price comparison sites), but few institutions are highly effective at
# converting these inquiries into digital sales.
# Leading banks use first- and third-party data
#
# (e.g., geospatial, browsing behavior), a robust
#
# marketing technology stack (360-degree view
#
# of customer, omnichannel campaigns), and an
#
# agile operating model (e.g., cross-functional
#
# marketing war rooms). With these elements in
#
# place, progress can be rapid; a North
#
# American institution tripled annual online
# product sales in 12 months.
# Nordics
# Latin America
# Poland
# Average
# Digital customer activity
# June 2018
# Digital sales penetration
# July 2017 – June 2018
# Market
# highest
# 1observed
# Market
# lowest
# 1observed
# Activity
# 2: 57pp
# Sales3: 48ppSingapore
# Activity
# 2: 31pp
# Sales3: 47pp
# United Kingdom
# Activity
# 2: 22pp
# Sales3: 45ppUnited States
# Activity
# 2: 37pp
# Sales3: 41pp
# Australia/
# New Zealand
# Activity
# 2: 25pp
# Sales3: 30pp
# Italy
# Exhibit 4
# Note: For Latin America, Italy, and the Nordics, only average shown.
# 1 Lowest/highest observed for each metric in given market - not necessarily the same bank
# 2 Activity = difference between highest and lowest observed digital customer activity
# 3 Sales = difference between highest and lowest observed digital sales penetration
# Source: McKinsey
# In most markets, there are wide gaps between banks in terms of
# digital performance.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'leading banks use first- and third-party data (e.g., geospatial, browsing behavior), a robust marketing technology stack (360-degree view of customer, omnichannel campaigns), and an agile operating model . a north american institution tripled annual online product sales in 12 months . for Latin America, Italy, and the Nordics, only average shown .'}]
#
# ---- Page No. 8----
# Original Text Length: 3765
# Original Text: 7Rewriting the rules: Succeeding in the new retail banking landscape
# 2. Customer experience is beginning to gener-
# ate meaningful separation in growth
# Across all retail businesses—including banks—
#
# customers now expect interactions to be simple,
# intuitive, and seamlessly connected across physical
#
# and digital touchpoints.  Banks are investing in meeting these expectations
# but have struggled to keep pace—focusing on the
# less-than-lofty goal of making the experience “less
# bad” for customers, rather than “outstanding.”
# Many banks are hampered by legacy IT
#
# infrastructures and siloed data. As a result, few
#
# banks are true leaders in terms of customer
#
# experience. Even for leading institutions, typically
# only one-half to two-thirds of customers rate their
#
# experience as excellent. This holds true across
#
# product categories, including those such as cards
#
# and deposits that have higher digital adoption rates.  The impact of this less-than-stellar performance is measurable. For example, McKinsey analysis
# shows that in the US, top-quartile banks in terms
# of experience have had meaningfully higher
# deposit growth over the past three years (
# Exhibit 5, page 8). Simply being good does not move the
# needle; customer impact really shows when banks
#
# offer outstanding experiences. The few
#
# “experience leaders” emerging in retail banking are
#
# generating higher growth than their peers by
#
# attracting new customers and deepening
# relationships with their existing customer base.
#
# Highly satisfied customers are two-and-a-half
#
# times more likely to open new accounts/products
#
# with their existing bank than those who are merely
#
# satisfied; they are also less price sensitive and
#
# generate positive word of mouth.
# These experience leaders are adopting tactics
# pioneered by digital-native companies in other
#
# sectors such as ecommerce, travel, and
# entertainment: setting a “north star” based on proven markers of differentiated experience (e.g.,
#
# UX design, carrying context across channels),
#
# redesigning journeys that matter most for digital-
#
# first customers and not just digital-only
# customers, and establishing integrated real-time
#
# measurement that cuts across products,
#
# channels, and employees. These banks know that
# customer experience is not just about the front-
#
# end look and feel, but that it requires discipline,
#
# focus, and investment in the following actions:    Focus on the journeys and sub-journeys that matter: The relative contribution of sub-
# journeys (e.g.,
# app downloading; activating account) in determining overall customer experience varies considerably. In fact, ten to
#
# fifteen sub-journeys have the biggest
#
# customer satisfaction impact for most
# products and should thus be the first priority.
#
# For instance, when opening a new deposit
# account, the researching options sub-journey
# has eight times the impact on customer
# satisfaction than other account-opening sub-
# journeys, on average (
# Exhibit 6, page 9). For banks, the key is to prioritize these high-
# impact sub-journeys and systematically
#
# redesign them from scratch—a process that
#
# can take about three to four months and
#
# result in at least a 15 to 20 percent lift in
#
# customer satisfaction.   Change the way you engage with customers. Experience leaders understand that digitization is not just about creating a cutting-edge online
#
# and mobile experience, and that satisfaction is
# shaped by customer experience across
#
# channels.1 The experience should be seamless, especially on journeys that are more
#
# likely to take place over multiple channels,
# such as new account opening, financial 1  Walter Rizzi and Zubin Taraporevala, “The balancing act: Omnichannel excellence in retail banking,” McKinsey.com, January 2019.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'customers expect interactions to be simple, intuitive, and seamlessly connected across physical and digital touchpoints . many banks are hampered by legacy IT infrastructures and siloed data . ten to fifteen sub-journeys have the biggest customer satisfaction impact for most products and should therefore be the first priority . the experience should be seamless, especially on journeys that are more likely to take place over multiple channels .'}]
#
# ---- Page No. 9----
# Original Text Length: 2023
# Original Text: 8Rewriting the rules: Succeeding in the new retail banking landscape
# advice, or issue resolution. One wealth manager equipped its front-line relationship
#
# managers with robo-advice algorithms that are
#
# in sync with what customers see on the self-
# directed channel—and provided the RMs with
#
# daily and weekly next-best-action
# recommendations to nudge their clients.
#
# Banks need to deploy these tools broadly and
#
# empower their front-line staff to play a more
#
# consultative role that blends human and digital
#
# recommendations. They will also need to
#
# revisit how these employees are incentivized,
#
# shifting to a longer-term view of relationships
#
# and profitability rather than just product sales.
#   Translate data into personalized products
# and real-time offers. The amount of data available on individual customers or
# prospects has exploded in recent years. The
#
# challenge is to convert this data into
# actionable nudges and highly relevant offers
#
# for customers that are delivered at the right
#
# moment. Credit card companies have long
#
# offered discounts on specific spending
#
# categories or with specific retailers. Today,
#
# however, they can improve loyalty and share
#
# of spending by providing location-specific
#
# offers right when a customer enters a coffee
#
# shop, movie theater, or car dealership. South
# Real differences in customer satisfaction
# 1CSAT (Percent of customers rating 9 or 10)
#  Leaders in customer experience are
# growing faster
# Deposit CAGR (2014-17)
# 65554939-26
# 5.93.2
# 46%
# Top
# quartile
# CSAT
# Bottom
# quartile
# CSAT
# Bottom
# quartile
# 3rdquartile
# 2nd
# quartile
# Top
# quartile
# Exhibit 5
# 1 Percentage of respondents that selected a 9 or 10 on a 10-point customer satisfaction scale. Question: “We would like to
# understand your experience with [product] with [Bank]. Overall, how satised or dissatised are you with [product] with [Bank]?
# ”Source: McKinsey 2018 Retail Banking Customer Experience Benchmark Survey.
# US retail banks with better customer experience are growing deposits
# faster.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'the amount of data available on individual customers or prospects has exploded in recent years . banks need to deploy these tools broadly and empower front-line staff to play a more consultative role that blends human and digital recommendations . the challenge is to convert this data into actionable nudges and highly relevant offers for customers that are delivered at the right moment .'}]
#
# ---- Page No. 10----
# Original Text Length: 1488
# Original Text: 9Rewriting the rules: Succeeding in the new retail banking landscape
# Africa’s Discovery, as an example, is
# launching a bank with product features that
#
# are informed by behavioral science and
#
# incentive design research (e.g., dynamic
#
# interest rates for savings and credit products
#
# that are tied to healthy financial behavior).
# 3. Productivity gains and returns to scale
#
# are back
# Larger retail banks have historically tended to be
#
# more efficient than their smaller competitors,
#
# benefiting from distribution network effects and
#
# the shared overhead for IT, infrastructure, and
#
# other shared services. Our analysis of over 3,000
# 515
# 01020253040
# 3545
# 5050055606570Importance
# Relative importance %
# 3Researching options
# Deposit sub-journeys
# 1Downloading the app
# Activating the account
# Learning about account features
# Completing the application
# Performance
# Journey SAT (top 2 boxes)
# 2Exhibit 6
# 1 Deposit example journeys shown; trend also holds true for credit card and mortgage account-opening sub-journeys.
# 2 Customer satisfaction with individual sub-journeys. Represents percentage of customers that rated the sub-journey 9 or 10 (on
# 10-point scale).
# 3 Relative importance is the amount that any individual sub-journey impacts the total journey score; calculated using a variance
#  decomposition approach.
# Source: McKinsey 2018 North American Retail Banking Journey Benchmarks
# Banks should prioritize the sub-journeys the have the most impact on
# customer experience.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'productivity gains and returns to scale are back Larger retail banks have historically tended to be more efficient than their smaller competitors . our analysis of over 3,000 515 01020253040 3545 5050055606570Importance Relative importance % 3Researching options Deposit sub-journeys 1Downloading the app Performance Journey SAT (top 2 boxes)'}]
#
# ---- Page No. 11----
# Original Text Length: 1983
# Original Text: 10Rewriting the rules: Succeeding in the new retail banking landscape
# banks around the globe shows that while there is
# variation across countries, larger institutions tend
#
# to be more efficient both in terms of cost-to-asset
#
# (Exhibit 7) and cost-to-income ratios. However,
# beyond a certain point, even larger institutions
# struggle to eke out efficiencies or realize benefits
#
# from scale. For example, even after several years
#
# of cost-cutting after the most recent financial
#
# crisis, large US retail banks have not made
#
# material improvements in productivity over the
#
# past decade (Exhibit 8).   We expect this paradigm to change over the next
# few years, as structural improvements in efficiency
#
# ratios and increasing returns to scale enable some
#
# large banks to become even more efficient. The
#
# reason is two-fold: first, advances in technologies
#
# such as robotic process automation, machine
#
# learning, and cognitive artificial intelligence—many
#
# of which are now mainstream and commercially
#
# viable—are unleashing a new wave of productivity
#
# improvements for financial institutions. Deployed
#
# effectively, these tools can reduce costs by as
# Country examples
# 32015-17 C/A, bps
# Lowest quintile
#  Quintile 3
# Quintile 2
# Quintile 4
# Top quintile
# Top 3 banks
# 349296
# 277
# 320307306
# -15%
# 11499
# 113948786
# -24%
# 184121111959295
# -49%
# 390316247150219184
# -53%
# ChinaIndiaJapan
# US-1-3-6-5
# 0-4-20
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# Average cost to assets
# 2015-2017 C/A, bps
# LowHigh
# Market share
# Log (Market share)
# 225%
# 5%1%Exhibit 7
# Linear regression
# 1Y = 50bps - 50x
# R2 = 8.2%
#
# P-value: 2x10
# -16
#   1 Linear regression based on sample of ~3000 banks (all countries included with a sample size larger than 30).
# 2 Market share dened as bank’s asset size divided by total assets of banks from the specic country.
# 3 Quintiles based on market share.
# Source: S&P Global Market Intelligence; McKinsey Panorama
# The efÞciency advantage for large retail banks holds true on a global
# level.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'efciency advantage for large retail banks holds true on a global level . but even after several years of cost-cutting after the most recent financial crisis, large US retail banks have not made material improvements in productivity over the past decade . the reason is two-fold: first, advances in technologies such as robotic process automation, machine learning, and cognitive artificial intelligence are unleashing a new wave of productivity improvements .'}]
#
# ---- Page No. 12----
# Original Text Length: 1441
# Original Text: 11Rewriting the rules: Succeeding in the new retail banking landscape
# much as 30 to 40 percent in customer-facing,
# middle-, and back-office activities, and
#
# fundamentally change how work is done.
# Dramatic change has already taken place in
#
# banking sectors such as capital markets, where
#
# algorithmic trading and automation are radically
#
# changing the talent profile and making a
#
# significant portion of existing jobs redundant.
# The second factor leading to a wave of productivity improvement in retail banking is the
#
# shift from physical to digital channels for
# customer acquisition. Banks with scale—and skills in leveraging that advantage—will achieve
# customer acquisition costs of up to two to three
#
# times lower than their smaller peers. Their
# outsized volumes of customer data will lead to
# better targeting and funnel conversion. As
# investments are shifted toward digital channels,
#
# the productivity gap between large and small
#
# banks will widen (Exhibit 9).  This dynamic has played out in more digitally
# mature industries, with firms like Amazon and
# Exhibit 8
# 1 Top 25 US banks by deposits in transaction accounts.
# Source: SNL; McKinsey analysis
# 705512092000
# 754016450650156065138002010307
# 0414
# 05082017
# 1011Cost/income ratio
# %Evolution of cost/income ratio for leading banks
# 1Lower
# quartile
# Median
# Upper
# quartile
# Most large US retail banks have struggled to improve productivity
# beyond a narrow efÞciency band.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'a wave of productivity improvement in retail banking is the shift from physical to digital channels for customer acquisition . this dynamic has played out in more digitally mature industries, with firms like amazon and Exhibit 8 1 Top 25 US banks by deposits in transaction accounts . a large US retail banks have struggled to improve productivity beyond a narrow efciency band .'}]
#
# ---- Page No. 13----
# Original Text Length: 1993
# Original Text: 12Rewriting the rules: Succeeding in the new retail banking landscape
# Priceline acquiring customers at a significantly lower cost than competitors. As in these
# industries, eventually a limited number of dominant
# banks will emerge, squeezing out undifferentiated
#
# mid-sized and smaller banks. There are early signs
#
# of this trend: undifferentiated smaller community
#
# banks in the US have lost a significant share of
#
# deposits over the last two to three years, while the
#
# three largest banks have gained share. Of course,
#
# scale is not everything. Banks that succeed in this
# new wave of productivity will also have taken the
#
# following actions:    Use cutting-edge technology to automate: Over the next few years, banks will increase their use
# of technologies such as natural language
# processing and artificial intelligence to automate
#
# customer-facing interactions and complex
#
# internal tasks. Already, legal and compliance
#
# departments are automating the extraction of
#
# data from documents and using algorithms to
#
# triage suspicious patterns for manual review.
#
# One leading global institution recently revamped
#
# its customer-care process with a raft of new
#
# technologies to identify potential FTE reductions
# Cost/income ratio
# %101001,000
# 25-30%
# 50-55%
# 70-75%
# Bank size
#
# $ billion assets
# Current cost curve
# Future cost curve
# 100%
# Exhibit 9
# Greater returns to scale,
#  driven by ability to leverage
# investments in customer analytics and experience
#
# without needing to scale the physical presence
# Structurally lower cost across the curve
# , driven by adoption of technologies like
#
# machine learning, artielligence,
#
# robotic process automation
# Lower cost of starting up
# , driven by
# open banking architecture (e.g.,
#
# API-enabled “bank in a box”) and
#
# cloud hosting
#  Source: SNL; S&P Market Intelligence; McKinsey analysis
# Over the next 5 years, we expect the industry cost curve to shift
# fundamentally downward, with greater returns to scale for larger
#
# institutions.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'undifferentiated small community banks in the us have lost a significant share of deposits over the last two to three years . the three largest banks have gained share . over the next few years, banks will increase their use of technologies such as natural language processing and artificial intelligence to automate customer-facing interactions and complex internal tasks . a leading global institution recently revamped its customer-care process with a raft of new technologies to identify potential FTE reductions .'}]
#
# ---- Page No. 14----
# Original Text Length: 3667
# Original Text: 13Rewriting the rules: Succeeding in the new retail banking landscape
# of more than 30 percent, and a North American
# bank used automation technologies to identify
# efficiency improvements of 20 percent in its
#
# finance function.
#   Build and reinforce the brand: With rising
# digital sales consumers have more choice
# than ever in selecting a financial services
# provider. However, our research shows that
#
# across most categories consumers actively
#
# consider only two to three products before
#
# deciding on a purchase. So it remains as
#
# important as ever for a bank to be part of the
# initial consideration set. Brands with superior
# awareness and recognition are not only more
#
# likely to be part of the initial consideration set
# but also achieve higher conversion rates than
# lesser-known brands when they are
#
# considered. A leading credit card provider in a
#
# major European market that invested heavily
#
# in brand awareness is now twice as likely to
#
# be actively considered—by 17 percent of
#
# consumers versus 7 to 10 percent for other
#
# brands—and experiences 50 percent higher
#
# conversion when considered compared to
#
# lesser-known brands.
# 2 The returns enjoyed by
# banks with superior recognition—in the form
#
# of lower acquisition costs—reinforce the
#
# benefits of scale and will be an advantage
# over time for larger institutions that can invest
# heavily in building and reinforcing their brand.
# 4. The unbundling and “rebundling” of
#
# retail banking
# The tight one-on-one retail banking relationships
#
# of old are unbundling. Forty percent of US
#
# households today hold a deposit account with
# more than one institution. It is common to have a
#
# mortgage with one bank, an unsecured loan with
# a different lender, and separate deposit and
# investment accounts. The banking relationship is
#
# fragmenting even faster in countries with higher
# digital adoption, such as the Netherlands and the
# UK, where the percentage of customers that use
#
# more than two providers has increased by 20
#
# percent over the past five years.
# This decline of customer loyalty provides a
# perfect context for firms seeking to enter banking
# in a selective way—focusing on the most
# profitable segments. Some attackers have
#
# demonstrated that despite incumbent banks’
# access to much more customer data, they can
#
# compete effectively on customer experience
#
# coupled with aggressive pricing to gain share.
#
# New entrants in financial services typically begin
# by focusing on a niche—making either a product
#
# or segment-focused play. For example,
#
# Wealthfront and Personal Capital in the US began
#
# with a sharp focus on mass affluent customers—
#
# providing robo advice aligned with financial goals
#
# at far less cost than traditional financial advisors.
# SoFi focused first on recent graduates from elite
#
# colleges, using student loan refi as a hook
#
# product. Their ambition, however, is to own the
#
# full banking relationship of this segment over
#
# time—providing cards, mortgage products, and
#
# broader banking services—although it remains to
#
# be seen how feasible this will prove in practice.
# The Open Banking movement, heralded by Europe’s second Payments Service Directive and
#
# the UK’s Open Banking Standards, has the
#
# potential to accelerate the unbundling of banking
# in the regions where it applies, leading to
#
# increasingly intense competition over the next few
#
# years.3 The requirement for banks to share data
# and provide access to consumer and small
# 2  January 2018 McKinsey research on 8,000 UK credit card applicants.
# 3Alessio Botta, Nunzio Digiacomo, Reinhard Höll, and Liz Oakes, “PSD2: Taking advantage of open-banking disruption,”
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'a leading credit card provider in a major european market is twice as likely to be actively considered . the returns enjoyed by banks with superior recognition will be an advantage over time for larger institutions that can invest heavily in building and reinforcing their brand . some attackers have demonstrated that despite incumbent banks’ access to more customer data, they can compete effectively on customer experience coupled with aggressive pricing to gain share .'}]
#
# ---- Page No. 15----
# Original Text Length: 3968
# Original Text: 14Rewriting the rules: Succeeding in the new retail banking landscape
# business accounts through a common framework
# of APIs is likely to fuel a wave of innovation and
# level the playing field for fintechs and technology
# providers seeking entry through payments or
#
# consumer financing. Recent McKinsey research
#
# shows that consumers are most interested in
#
# marketplace concepts that simplify comparisons
# and make it easier to switch between providers
#
# based on their needs and preferences.
# The trend toward unbundling in financial services is
# well under way, but where it will lead is still an open
#
# question. In industries such as music, television,
# ecommerce, and transportation, digital distribution
#
# led to unbundling that destroyed value for
#
# incumbents in the short term; over time, consumers
# tend to converge on a single provider—often an
#
# attacker. In this context, firms that effectively
#
# orchestrate platform or ecosystem environments
#
# tend to eventually emerge as winners.  The history of the music industry over the last 20 years provides a possible model for how things
#
# will go in banking (Exhibit 10). Until the 1990s, music distribution was dominated by stores
#
# selling tracks that record companies “bundled”
#
# onto albums. In the early 2000s, digital
# distribution, especially via iTunes, radically
#
# reduced distribution costs. Consumers could now
#
# “unbundle” albums by purchasing individual
#
# tracks online; not surprisingly, many record stores
#
# went out of business. Over the past few years,
# however, we have seen a “rebundling” in the form
#
# of the streaming playlist. Streaming services are
#
# now the dominant distribution channel, with a few
# large players such as Spotify and Apple emerging
# as winners. The success of these platforms is
# based on their ability to create highly
#
# personalized bundles based on consumer needs
# and preferences, and a superior interface without
#
# the friction of purchasing tracks individually.
#
# Leaders have created significant value for
#
# consumers by using customer data and insights to deliver a superior experience, rather than by manufacturing the underlying product.
# If we apply this scenario to banking, winning firms will be those that leverage superior access to
# customer data to provide truly differentiated and
#
# cutting-edge experiences—potentially extending
# beyond financial products and services. To do
#
# this effectively, banks will need to retain privileged
#
# access to information about consumers’ sources
#
# and use of funds, especially through payments
#
# and transaction activity. Banks that rebundle
#
# effectively will use this data to deliver compelling
#
# and integrated experiences that provide seamless
#
# funding, investment, payments, and money
# movement capabilities. The bottom line is that in
# order to reverse the unbundling of financial
#
# services, banks need to make it worthwhile for
# consumers to have a relationship with one
#
# institution; they need to deliver not only simplicity
# and convenience, but also superior value. Only a
# few banks in each market are likely to be able to
#
# succeed with this strategy.
# Already, large technology firms such as Amazon
# are extending into parts of the financial services
#
# value chain, starting with areas where they have a
#
# data advantage such as payments, short-term
# financing for purchases, and working capital
#
# loans for merchants on their platform. To counter
#
# the unbundling of their most profitable products,
#
# banks need to develop capabilities that few
# currently possess, and follow the lead of
#
# successful technology platforms:    Retain superior access to data on transactions and financial behavior: As vast amounts of data are captured by tech firms on
#
# consumers’ behavior and preferences, one of
#
# the last bastions of valuable information is
# data on transactions and financial behavior. To
#
# retain unparalleled access to this data, banks
#
# will need to continue to own the transaction
# --
# Summarized Text Length: 1
# [{'summary_text': 'the trend toward unbundling in financial services is well under way, but where it will lead is still an open question . the history of the music industry over the last 20 years provides a possible model for how things will go in banking . banks need to retain privileged access to information about consumers’ sources and use of funds, especially through payments and transaction activity .'}]
#
# ---- Page No. 16----
# Original Text Length: 1723
# Original Text: 15Rewriting the rules: Succeeding in the new retail banking landscape
# layer, giving them a full view of inbound and
# outbound activity, to form a complete picture
#
# of consumer balance sheets. Historically, this
#
# required a bank to be a customer’s primary
#
# checking account provider; over time, we
#
# expect that institutions could do this without
# necessarily owning the checking account
# relationship. In some cases, payments or
#
# transaction providers could see a significant
#
# share of customers’ spend volume. Financial
#
# aggregators that sit on top of a suite of
#
# products and services that are manufactured
# by others may also be in a position to capture
# a broad spectrum of customer activity and
#
# use it to build an analytics advantage.    Leverage insights to develop innovative products and features: The traditional suite of products that financial institutions offer has
#
# remained largely unchanged over the past few
#
# decades—e.g., checking accounts, lending,
# cards/payments, wealth management—and is
#
# often structurally hard to change given how
#
# banks are organized. More nimble firms will be
# Market
# concentration
# Industry
#
# maturity
# 1990s2000s2010s
# Exhibit 10
# Streaming services
#
# emerge, focusing on
#
# customer experience
#
# and using analytics to
# “rebundle” tracks into
# playlists that are
#
# tailored to individuals
# Fully unbundled music
# delivery, characterized
#
# by individuals
#
# purchasing individual
#
# tracks through digital
#
# channels and burning
#
# bespoke CDs
# Music delivered as
# “albums,” pre-bundled
# by a small number of
#
# record labels onto CDs
#  Source: McKinsey analysis
# The unbundling and rebundling in the music industry may provide a
# possible model for retail banking distribution.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'financial aggregators that sit on top of a suite of products and services may also be in a position to capture a broad spectrum of customer activity and use it to build an analytics advantage . the traditional suite of services that financial institutions offer has remained largely unchanged over the past few decades—e.g., checking accounts, lending, cards/payments, wealth management—and is often structurally hard to change .'}]
#
# ---- Page No. 17----
# Original Text Length: 1772
# Original Text: 16Rewriting the rules: Succeeding in the new retail banking landscape
# able to leverage insights to create unique
# offerings—for example, cash in a checking
#
# account could automatically be optimized for
# return based on financial behaviors and spend
#
# patterns without needing to ring-fence and
#
# transfer it to a separate high-yield deposit or
# brokerage account. Or, when a customer
#
# takes a short-term unsecured loan the rate
#
# might be optimized based on the steadiness
# of their income stream and savings
#
# accumulated each month, and they could
# collateralize against balances in other
# accounts with the bank.   Extend beyond purely financial services and
# products over time: There are a couple of
# clear benefits that financial institutions are
#
# likely to have relative to ecosystems being
#
# created by large tech firms. Superior access
#
# to financial information enables them to create
#
# faster and more precise offers for big-ticket
#
# products that have financing needs associated
#
# with them (e.g., homes or cars). For these
# types of products, banks could be well-
#
# positioned to own the full customer journey,
# including the browsing experience and the
# transaction. One Northern European bank has
#
# developed a mobile app that integrates house
# searches, booking viewings, budgeting,
#
# transactions, and help with setting up a new
# home (e.g., utilities, appliances, and
# renovation).
# 4 In the US, Capital One’s Auto
# Navigator facilitates a seamless search
#
# experience for car buyers and can provide
#
# instant approval for financing before they visit
#
# a dealership. 4  Miklós Dietz, Reka Hamvai, Paul Jenkins, Miklos Radnai, and Michael Yee, “Deep insights, broad solutions: How banks can win in
# the vast housing ecosystem,” McKinsey.com, June 2018.
#
# --
# Summarized Text Length: 1
# [{'summary_text': 'one Northern European bank has developed a mobile app that integrates house searches, booking viewings, budgeting, transactions, and help with setting up a new home . capital One’s Auto Navigator facilitates a seamless search experience for car buyers and can provide instant approval for financing before they visit a dealership . a customer can take a short-term unsecured loan to a high-yield deposit or brokerage account .'}]
# Your max_length is set to 300, but you input_length is only 48. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# ---- Page No. 18----
# Original Text Length: 2282
# Original Text: 17Rewriting the rules: Succeeding in the new retail banking landscape
# The path forward
# In the near term, competition in retail banking is
# likely to intensify, with only a few banks emerg-
#
# ing as winners. These banks will take bold steps
# now to establish a formidable position that fends
# off new entrants and smaller attackers. Retail
#
# banking leaders should consider and debate the
# following questions as they face the challenges
# of the coming years:  1.What is our strategy to increase customer
# growth over the next three to five years, not
#
# just protect existing share of wallet?
# 2.How bold can we be with our distribution
# plan, and will it be effective two to three years
#
# from now?
# 3.Are we on track to deliver a superior customer
# experience in the next 12 months? What ca-
# pabilities will differentiate us from the compe-
#
# tition?  4.How can we deploy new technologies to re-
# duce our cost structure? Are we building the
# infrastructure to capture and harness data so
# we can benefit from scale?
# 5.Do we need to reposition or reinforce our
# brand, or develop new attacker brands, to tap
# into new customer segments?  6.Are we prepared for the impact of Open Bank-
# ing and similar rules that pave the way for at-
# tackers and fintechs? What offensive and
#
# defensive moves do we need to make?  7.How do we position ourselves to rebundle
# products and services around customer
#
# needs? How should we design our platform
# and what partnerships should we pursue?   Our view is that retail banking is at an inflection
# point, and that the pace of change will accelerate
# significantly over the next three to five years. Suc-
#
# cess will require clarity in direction, and speed
#
# and agility in execution. Retail banks that capital-
# ize on current shifts in the market will emerge
#
# with a winning position in their core markets and
#
# begin to compete across borders.
# Vaibhav Gujral is a partner and Nick Malik is a senior partner, both in McKinsey’s New York office.
# Zubin Taraporevala is a senior partner in the London office.
#
# The authors would like to thank Ashwin Adarkar, Jacob Dahl, Filippo Delzi, Miklos Dietz, Dave Elzinga,
#
# Darius Imregun, Somesh Khanna, Marc Levesque, Alejandro Martinez, and Robert Schiff for their
# contributions to this article.
# --
# Summarized Text Length: 1
# [{'summary_text': 'retail banking leaders should consider and debate the following questions as they face the challenges of the coming years . the authors would like to thank Ashwin Adarkar, Jacob Dahl, Filippo Delzi, Miklos Dietz, Dave Elzinga, Darius Imregun, Somesh Khanna, Marc Levesque, Alejandro Martinez, and Robert Schiff for their contributions .'}]
#
# ---- Page No. 19----
# Original Text Length: 133
# Original Text: Global Banking Practice  February 2019
# Copyright © McKinsey & Company
# www.mckinsey.com/industries/financial-services/our-insights
#
# --
# Summarized Text Length: 1
# [{'summary_text': "global banking practice February 2019 Copyright  McKinsey & Company www.mckinsey.com/industries/financial-services/our-insights.html   Copyright: 'i'm not a banker, but i don't know what I'm doing'"}]

# %% [markdown]
# # ABSA with spaCy

# %% [markdown]
# ### Extract Sentences from the Text

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/jupyter/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# cleaned_data = clean_text("extract_2.txt") 

# Clean the Text 
cleaned_data = clean_text(document1, False) 

# print('\n-\n'.join(nltk.tokenize.sent_tokenize(cleaned_data)))

sentences = nltk.tokenize.sent_tokenize(cleaned_data)

print(sentences)
# Out:
# ['Succeeding in the new retail banking landscape Retail banks have long competed on distribution, realizing economies of scale through network effects and investments in brand and infrastructure.', 'But even those scale economies had limits above a certain size.', 'As a result, in most retail banking markets, a few large institutions, operating at similar efficiency ratios, dominate market share.', 'Changes to the retail banking business model have mostly come in response to regulatory shifts, as opposed to a purposeful reimagining of what the winning bank of the future will look like.', 'Retail banks have also not kept pace with the improvements in customer experience seen in other consumer industries.', 'Few banks stand out for innovation in customer interaction models or branch formats.', 'Marketing investments have traditionally focused on brand building and increasing loyalty: a reputable brand stood for trust and security and became a moat, providing protection against new entrants to the sector.', 'Finally, most banks offer similar products, with limited innovation in features.', 'Today, the moats that banks have built are more likely to restrict their own progress than protect them from attackers.', 'Four shifts are reshaping the global retail banking landscape to the point where banks need to fundamentally rethink what it takes to compete and win.', 'This should be an urgent priority for banks.', 'The pace of change will likely accelerate, with a select set of large-scale winners emerging in the next three to five years that will gain share in their core markets and begin to compete across borders, leaving many sub-scale institutions scrambling for relevance.', 'Rewriting the rules: Succeeding in the new retail banking landscape  2 Rewriting the rules: Succeeding in the new retail banking landscape Four shifts are reshaping retail banking Four secular shifts are changing the way retail banks will compete in the coming years:    The traditional distribution-led growth formula is losing relevance, with a breakdown in the relationship between branch footprint and growth.', 'Banks are now competing on customer experience, with leaders growing faster than their competitors.', 'Scale economics are back—banks that excel at deploying new technologies (e.g., automation and machine learning) and those with a more digital-centric channel mix will have a structural cost advantage.', 'The retail banking relationship is getting unbundled along product lines, fueled by digitization and, increasingly, by regulation— and the biggest profit pools are under attack.', 'A few banks will be able to temper and reverse this trend, using superior data and analytics capabilities to build deeper and broader relationships with their customers.', 'In the near term, these shifts will combine to intensify competition as new entrants and incumbents seek to push past traditional boundaries.', 'More than  100  digital attacker banks have launched in the last few years globally— including N 26 , Monzo and Revolut in Europe; WeBank, Digibank, Jenius in Asia; SoFi, Marcus, Moven in the US; Nubank in South America— while many incumbents have launched or are considering launching digital-first models.', 'Over the next three to five years, we expect a few players to emerge from this competitive scrum to gain dominant share in their core markets and possibly beyond.', 'These firms will have taken bold and decisive actions to capitalize on the shifts that are reshaping the industry.', 'In some cases, these winners will be incumbents that build on an already significant share; in others, they will be institutions newer to the banking industry, which use their agility, strategic aggressiveness, and sharp execution to attract customers.', '1 .', 'The traditional distribution-led growth formula no longer applies Until the financial crisis in  2007 , a retail bank’s total share of deposits was tightly linked to the size of its branch network.', 'Even as internet u ...

# %% [markdown]
# ### Split the sentences to get target aspects

# %%
for sentence in sentences:
  doc = nlp(sentence)
  for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
      token.pos_,[child for child in token.children])
# Out:
# Succeeding advcl competed VERB VERB [in]
# in prep Succeeding VERB ADP [landscape]
# the det landscape NOUN DET []
# new amod landscape NOUN ADJ []
# retail amod banking NOUN ADJ []
# banking compound landscape NOUN NOUN [retail]
# landscape pobj in ADP NOUN [the, new, banking]
# Retail amod banks NOUN ADJ []
# banks nsubj competed VERB NOUN [Retail]
# have aux competed VERB AUX []
# long advmod competed VERB ADV []
# competed ROOT competed VERB VERB [Succeeding, banks, have, long, on, ,, realizing, .]
# on prep competed VERB ADP [distribution]
# distribution pobj on ADP NOUN []
# , punct competed VERB PUNCT []
# realizing advcl competed VERB VERB [economies, through]
# economies dobj realizing VERB NOUN [of]
# of prep economies NOUN ADP [scale]
# scale pobj of ADP NOUN []
# through prep realizing VERB ADP [effects]
# network compound effects NOUN NOUN []
# effects pobj through ADP NOUN [network, and, investments, in]
# and cc effects NOUN CCONJ []
# investments conj effects NOUN NOUN []
# in prep effects NOUN ADP [brand]
# brand pobj in ADP NOUN [and, infrastructure]
# and cc brand NOUN CCONJ []
# infrastructure conj brand NOUN NOUN []
# . punct competed VERB PUNCT []
# But cc had VERB CCONJ []
# even advmod economies NOUN ADV []
# those det economies NOUN DET []
# scale compound economies NOUN NOUN []
# economies nsubj had VERB NOUN [even, those, scale]
# had ROOT had VERB VERB [But, economies, limits, .]
# limits dobj had VERB NOUN [above]
# above prep limits NOUN ADP [size]
# a det size NOUN DET []
# certain amod size NOUN ADJ []
# size pobj above ADP NOUN [a, certain]
# . punct had VERB PUNCT []
# As prep dominate VERB ADP [result]
# a det result NOUN DET []
# result pobj As ADP NOUN [a]
# , punct dominate VERB PUNCT []
# in prep dominate VERB ADP [markets]
# most amod markets NOUN ADJ []
# retail amod banking NOUN ADJ []
# banking compound markets NOUN NOUN [retail]
# markets pobj in ADP NOUN [most, banking]
# , punct dominate VERB PUNCT []
# a det institutions NOUN DET []
# few amod institutions NOUN ADJ []
# large amod institutions NOUN ADJ []
# institutions nsubj dominate VERB NOUN [a, few, large, ,, operating, ,]
# , punct institutions NOUN PUNCT []
# operating acl institutions NOUN VERB [at]
# at prep operating VERB ADP [ratios]
# similar amod ratios NOUN ADJ []
# efficiency compound ratios NOUN NOUN []
# ratios pobj at ADP NOUN [similar, efficiency]
# , punct institutions NOUN PUNCT []
# dominate ROOT dominate VERB VERB [As, ,, in, ,, institutions, share, .]
# market compound share NOUN NOUN []
# share dobj dominate VERB NOUN [market]
# . punct dominate VERB PUNCT []
# Changes nsubj come VERB NOUN [to]
# to prep Changes NOUN ADP [model]
# the det model NOUN DET []
# retail amod banking NOUN ADJ []
# banking compound model NOUN NOUN [retail]
# business compound model NOUN NOUN []
# model pobj to ADP NOUN [the, banking, business]
# have aux come VERB AUX []
# mostly advmod come VERB ADV []
# come ROOT come VERB VERB [Changes, have, mostly, in, ,, opposed, .]
# in prep come VERB ADP [response]
# response pobj in ADP NOUN [to]
# to prep response NOUN ADP [shifts]
# regulatory amod shifts NOUN ADJ []
# shifts pobj to ADP NOUN [regulatory]
# , punct come VERB PUNCT []
# as mark opposed VERB ADP []
# opposed advcl come VERB VERB [as, to]
# to prep opposed VERB ADP [reimagining]
# a det reimagining NOUN DET []
# purposeful amod reimagining NOUN ADJ []
# reimagining pobj to ADP NOUN [a, purposeful, of]
# of prep reimagining NOUN ADP [look]
# what pobj like ADP PRON []
# the det bank NOUN DET []
# winning amod bank NOUN VERB []
# bank nsubj look VERB NOUN [the, winning, of]
# of prep bank NOUN ADP [future]
# the det future NOUN DET []
# future pobj of ADP NOUN [the]
# will aux look VERB AUX []
# look pcomp of ADP VERB [bank, will, like]
# like prep look VERB ADP [what]
# . punct come VERB PUNCT []
# Retail amod banks NOUN ADJ []
# banks nsubj kept VERB NOUN [Retail]
# have aux kept VERB AUX []
# also advmod kept VERB ADV []
# not neg kept VERB PART []
# kept ROOT kept VERB VERB [banks, have, also, not, pace, with, .]
# pace dobj kept VERB NOUN []
# with prep kept VERB ADP [improvements]
# the det improvements NOUN DET []
# improvements pobj with ADP NOUN [the, in]
# in prep improvements NOUN ADP [experience]
# customer compound experience NOUN NOUN []
# experience pobj in ADP NOUN [customer, seen]
# seen acl experience NOUN VERB [in]
# in prep seen VERB ADP [industries]
# other amod industries NOUN ADJ []
# consumer compound industries NOUN NOUN []
# industries pobj in ADP NOUN [other, consumer]
# . punct kept VERB PUNCT []
# Few amod banks NOUN ADJ []
# banks nsubj stand VERB NOUN [Few]
# stand ROOT stand VERB VERB [banks, out, for, .]
# out prt stand VERB ADP []
# for prep stand VERB ADP [innovation]
# innovation pobj for ADP NOUN [in]
# in prep innovation NOUN ADP [models]
# customer compound interaction NOUN NOUN []
# interaction compound models NOUN NOUN [customer]
# models pobj in ADP NOUN [interaction, or, formats]
# or cc models NOUN CCONJ []
# branch compound formats NOUN NOUN []
# formats conj models NOUN NOUN [branch]
# . punct stand VERB PUNCT []
# Marketing compound investments NOUN NOUN []
# investments nsubj focused VERB NOUN [Marketing]
# have aux focused VERB AUX []
# traditionally advmod focused VERB ADV []
# focused ccomp stood VERB VERB [investments, have, traditionally, on, increasing]
# on prep focused VERB ADP [building]
# brand compound building NOUN NOUN []
# building pobj on ADP NOUN [brand, and]
# and cc building NOUN CCONJ []
# increasing advcl focused VERB VERB [loyalty]
# loyalty dobj increasing VERB NOUN []
# : punct stood VERB PUNCT []
# a det brand NOUN DET []
# reputable amod brand NOUN ADJ []
# brand nsubj stood VERB NOUN [a, reputable]
# stood ROOT stood VERB VERB [focused, :, brand, for, and, became, .]
# for prep stood VERB ADP [trust]
# trust pobj for ADP NOUN [and, security]
# and cc trust NOUN CCONJ []
# security conj trust NOUN NOUN []
# and cc stood VERB CCONJ []
# became conj stood VERB VERB [moat, ,, providing]
# a det moat NOUN DET []
# moat attr became VERB NOUN [a]
# , punct became VERB PUNCT []
# providing advcl became VERB VERB [protection, to]
# protection dobj providing VERB NOUN [against]
# against prep protection NOUN ADP [entrants]
# new amod entrants NOUN ADJ []
# entrants pobj against ADP NOUN [new]
# to prep providing VERB ADP [sector]
# the det sector NOUN DET []
# sector pobj to ADP NOUN [the]
# . punct stood VERB PUNCT []
# Finally advmod offer VERB ADV []
# , punct offer VERB PUNCT []
# most amod banks NOUN ADJ []
# banks nsubj offer VERB NOUN [most]
# offer ROOT offer VERB VERB [Finally, ,, banks, products, ,, with, .]
# similar amod products NOUN ADJ []
# products dobj offer VERB NOUN [similar]
# , punct offer VERB PUNCT []
# with prep offer VERB ADP [innovation]
# limited amod innovation NOUN ADJ []
# innovation pobj with ADP NOUN [limited, in]
# in prep innovation NOUN ADP [features]
# features pobj in ADP NOUN []
# . punct offer VERB PUNCT []
# Today npadvmod are AUX NOUN []
# , punct are AUX PUNCT []
# the det moats NOUN DET []
# moats nsubj are AUX NOUN [the, built]
# that dobj built VERB DET []
# banks nsubj built VERB NOUN []
# have aux built VERB AUX []
# built relcl moats NOUN VERB [that, banks, have]
# are ROOT are AUX AUX [Today, ,, moats, likely, .]
# more advmod likely ADJ ADV []
# likely acomp are AUX ADJ [more, restrict]
# to aux restrict VERB PART []
# restrict xcomp likely ADJ VERB [to, progress, protect]
# their poss progress NOUN PRON []
# own amod progress NOUN ADJ []
# progress dobj restrict VERB NOUN [their, own]
# than mark protect VERB SCONJ []
# protect advcl restrict VERB VERB [than, them, from]
# them dobj protect VERB PRON []
# from prep protect VERB ADP [attackers]
# attackers pobj from ADP NOUN []
# . punct are AUX PUNCT []
# Four nummod shifts NOUN NUM []
# shifts nsubj reshaping VERB NOUN [Four]
# are aux reshaping VERB AUX []
# reshaping ROOT reshaping VERB VERB [shifts, are, landscape, to, .]
# the det landscape NOUN DET []
# global amod landscape NOUN ADJ []
# retail amod banking NOUN ADJ []
# banking compound landscape NOUN NOUN [retail]
# landscape dobj reshaping VERB NOUN [the, global, banking]
# to prep reshaping VERB ADP [point]
# the det point NOUN DET []
# point pobj to ADP NOUN [the, need]
# where advmod need VERB ADV []
# banks nsubj need VERB NOUN []
# need relcl point NOUN VERB [where, banks, rethink]
# to aux rethink VERB PART []
# fundamentally advmod rethink VERB ADV []
# rethink xcomp need VERB VERB [to, fundamentally, takes]
# what dobj takes VERB PRON []
# it nsubj takes VERB PRON []
# takes ccomp rethink VERB VERB [what, it, compete]
# to aux compete VERB PART []
# compete advcl takes VERB VERB [to, and, win]
# and cc compete VERB CCONJ []
# win conj compete VERB VERB []
# . punct reshaping VERB PUNCT []
# This nsubj be VERB DET []
# should aux be VERB AUX []
# be ROOT be VERB VERB [This, should, priority, .]
# an det priority NOUN DET []
# urgent amod priority NOUN ADJ []
# priority attr be VERB NOUN [an, urgent, for]
# for prep priority NOUN ADP [banks]
# banks pobj for ADP NOUN []
# . punct be VERB PUNCT []
# The det pace NOUN DET []
# pace nsubj accelerate VERB NOUN [The, of]
# of prep pace NOUN ADP [change]
# change pobj of ADP NOUN []
# will aux accelerate VERB AUX []
# likely advmod accelerate VERB ADV []
# accelerate ROOT accelerate VERB VERB [pace, will, likely, ,, with, .]
# , punct accelerate VERB PUNCT []
# with prep accelerate VERB ADP [set]
# a det set NOUN DET []
# select amod set NOUN ADJ []
# set pobj with ADP NOUN [a, select, of, gain]
# of prep set NOUN ADP [winners]
# large amod scale NOUN ADJ []
# - punct scale NOUN PUNCT []
# scale compound winners NOUN NOUN [large, -]
# winners pobj of ADP NOUN [scale, emerging]
# emerging acl winners NOUN VERB [in]
# in prep emerging VERB ADP [years]
# the det years NOUN DET []
# next amod years NOUN ADJ []
# three quantmod five NUM NUM []
# to quantmod five NUM PART []
# five nummod years NOUN NUM [three, to]
# years pobj in ADP NOUN [the, next, five]
# that nsubj gain VERB DET []
# will aux gain VERB AUX []
# gain relcl set NOUN VERB [that, will, share, in, and, begin]
# share dobj gain VERB NOUN []
# in prep gain VERB ADP [markets]
# their poss markets NOUN PRON []
# core compound markets NOUN NOUN []
# markets pobj in ADP NOUN [their, core]
# and cc gain VERB CCONJ []
# begin conj gain VERB VERB [compete, ,, leaving]
# to aux compete VERB PART []
# compete xcomp begin VERB VERB [to, across]
# across prep compete VERB ADP [borders]
# borders pobj across ADP NOUN []
# , punct begin VERB PUNCT []
# leaving advcl begin VERB VERB [institutions]
# many amod institutions NOUN ADJ []
# sub amod institutions NOUN ADJ []
# - amod institutions NOUN ADJ []
# scale amod institutions NOUN ADJ []
# institutions dobj leaving VERB NOUN [many, sub, -, scale, scrambling]
# scrambling acl institutions NOUN VERB [for]
# for prep scrambling VERB ADP [relevance]
# relevance pobj for ADP NOUN []
# . punct accelerate VERB PUNCT []
# Rewriting advcl   SPACE VERB [rules]
# the det rules NOUN DET []
# rules dobj Rewriting VERB NOUN [the]
# : punct   SPACE PUNCT []
# Succeeding csubj   SPACE VERB [in]
# in prep Succeeding VERB ADP [landscape]
# the det landscape NOUN DET []
# new amod landscape NOUN ADJ []
# retail amod banking NOUN ADJ []
# banking compound landscape NOUN NOUN [retail]
# landscape pobj in ADP NOUN [the, new, banking]
#   compound 2 NUM SPACE [Rewriting, :, Succeeding]
# 2 dep reshaping VERB NUM [ , Rewriting]
# Rewriting acl 2 NUM VERB [rules]
# the det rules NOUN DET []
# rules dobj Rewriting VERB NOUN [the]
# : punct reshaping VERB PUNCT []
# Succeeding csubj reshaping VERB VERB [in]
# in prep Succeeding VERB ADP [landscape]
# the det landscape NOUN DET []
# new amod landscape NOUN ADJ []
# retail amod banking NOUN ADJ []
# banking compound landscape NOUN NOUN [retail]
# landscape pobj in ADP NOUN [the, new, banking]
# Four nummod shifts NOUN NUM []
# shifts nsubj reshaping VERB NOUN [Four]
# are aux reshaping VERB AUX []
# reshaping ROOT reshaping VERB VERB [2, :, Succeeding, shifts, are, banking, changing, losing, .]
# retail amod banking NOUN ADJ []
# banking dobj reshaping VERB NOUN [retail, Four]
# Four nummod banking NOUN NUM []
# secular amod shifts NOUN ADJ []
# shifts nsubj changing VERB NOUN [secular]
# are aux changing VERB AUX []
# changing ccomp reshaping VERB VERB [shifts, are, way, :]
# the det way NOUN DET []
# way dobj changing VERB NOUN [the, compete]
# retail amod banks NOUN ADJ []
# banks nsubj compete VERB NOUN [retail]
# will aux compete VERB AUX []
# compete relcl way NOUN VERB [banks, will, in]
# in prep compete VERB ADP [years]
# the det years NOUN DET []
# coming amod years NOUN VERB []
# years pobj in ADP NOUN [the, coming]
# : punct changing VERB PUNCT []
#     meta losing VERB SPACE []
# The det formula NOUN DET []
# traditional amod formula NOUN ADJ []
# distribution npadvmod led VERB NOUN []
# - punct led VERB PUNCT []
# led amod formula NOUN VERB [distribution, -]
# growth compound formula NOUN NOUN []
# formula nsubj losing VERB NOUN [The, traditional, led, growth]
# is aux losing VERB AUX []
# losing conj reshaping VERB VERB [   , formula, is, relevance, ,, with]
# relevance dobj losing VERB NOUN []
# , punct losing VERB PUNCT []
# with prep losing VERB ADP [breakdown]
# a det breakdown NOUN DET []
# breakdown pobj with ADP NOUN [a, in]
# in prep breakdown NOUN ADP [relationship]
# the det relationship NOUN DET []
# relationship pobj in ADP NOUN [the, between]
# between prep relationship NOUN ADP [footprint]
# branch compound footprint NOUN NOUN []
# footprint pobj between ADP NOUN [branch, and, growth]
# and cc footprint NOUN CCONJ []
# growth conj footprint NOUN NOUN []
# . punct reshaping VERB PUNCT []
# Banks nsubj competing VERB NOUN []
# are aux competing VERB AUX []
# now advmod competing VERB ADV []
# competing ROOT competing VERB VERB [Banks, are, now, on, ,, with, .]
# on prep competing VERB ADP [experience]
# customer compound experience NOUN NOUN []
# experience pobj on ADP NOUN [customer]
# , punct competing VERB PUNCT []
# with prep competing VERB ADP [growing]
# leaders nsubj growing VERB NOUN []
# growing pcomp with ADP VERB [leaders, faster]
# faster advmod growing VERB ADV [than]
# than prep faster ADV SCONJ [competitors]
# their poss competitors NOUN PRON []
# competitors pobj than SCONJ NOUN [their]
# . punct competing VERB PUNCT []
# Scale compound economics NOUN NOUN []
# economics nsubj are AUX NOUN [Scale, banks]
# are ROOT are AUX AUX [economics, back, —, have]
# back advmod are AUX ADV []
# — punct are AUX PUNCT []
# banks appos economics NOUN NOUN [excel, and, those]
# that nsubj excel VERB DET []
# excel relcl banks NOUN VERB [that, at]
# at prep excel VERB ADP [deploying]
# deploying pcomp at ADP VERB [technologies]
# new amod technologies NOUN ADJ []
# technologies dobj deploying VERB NOUN [new, (, automation, )]
# ( punct technologies NOUN PUNCT []
# e.g. advmod automation NOUN ADV []
# , punct automation NOUN PUNCT []
# automation appos technologies NOUN NOUN [e.g., ,, and, learning]
# and cc automation NOUN CCONJ []
# machine compound learning NOUN NOUN []
# learning conj automation NOUN NOUN [machine]
# ) punct technologies NOUN PUNCT []
# and cc banks NOUN CCONJ []
# those conj banks NOUN DET [with]
# with prep those DET ADP [mix]
# a det mix NOUN DET []
# more advmod centric NOUN ADV []
# digital amod centric NOUN ADJ []
# - punct centric NOUN PUNCT []
# centric amod mix NOUN NOUN [more, digital, -]
# channel compound mix NOUN NOUN []
# mix pobj with ADP NOUN [a, centric, channel]
# will aux have VERB AUX []
# have conj are AUX VERB [will, advantage, .]
# a det advantage NOUN DET []
# structural amod advantage NOUN ADJ []
# cost compound advantage NOUN NOUN []
# advantage dobj have VERB NOUN [a, structural, cost]
# . punct have VERB PUNCT []
# The det relationship NOUN DET []
# retail amod banking NOUN ADJ []
# banking compound relationship NOUN NOUN [retail]
# relationship nsubj getting VERB NOUN [The, banking]
# is aux getting VERB AUX []
# getting ROOT getting VERB VERB [relationship, is, unbundled, and, are]
# unbundled acomp getting VERB ADJ [along]
# along prep unbundled ADJ ADP [lines]
# product compound lines NOUN NOUN []
# lines pobj along ADP NOUN [product, ,, fueled, —]
# , punct lines NOUN PUNCT []
# fueled acl lines NOUN VERB [by, and, ,, increasingly, ,, by]
# by agent fueled VERB ADP [digitization]
# digitization pobj by ADP NOUN []
# and cc fueled VERB CCONJ []
# , punct fueled VERB PUNCT []
# increasingly conj fueled VERB ADV []
# , punct fueled VERB PUNCT []
# by agent fueled VERB ADP [regulation]
# regulation pobj by ADP NOUN []
# — punct lines NOUN PUNCT []
# and cc getting VERB CCONJ []
# the det pools NOUN DET []
# biggest amod pools NOUN ADJ []
# profit compound pools NOUN NOUN []
# pools nsubj are VERB NOUN [the, biggest, profit]
# are conj getting VERB VERB [pools, under, .]
# under prep are VERB ADP [attack]
# attack pobj under ADP NOUN []
# . punct are VERB PUNCT []
# A det banks NOUN DET []
# few amod banks NOUN ADJ []
# banks nsubj be VERB NOUN [A, few]
# will aux be VERB AUX []
# be ROOT be VERB VERB [banks, will, able, .]
# able acomp be VERB ADJ [temper]
# to aux temper VERB PART []
# temper xcomp able ADJ VERB [to, and, reverse]
# and cc temper VERB CCONJ []
# reverse conj temper VERB VERB [trend, ,, using]
# this det trend NOUN DET []
# trend dobj reverse VERB NOUN [this]
# , punct reverse VERB PUNCT []
# using advcl reverse VERB VERB [capabilities, build]
# superior amod data NOUN ADJ []
# data nmod capabilities NOUN NOUN [superior, and, analytics]
# and cc data NOUN CCONJ []
# analytics conj data NOUN NOUN []
# capabilities dobj using VERB NOUN [data]
# to aux build VERB PART []
# build xcomp using VERB VERB [to, relationships]
# deeper amod relationships NOUN ADJ [and, broader]
# and cc deeper ADJ CCONJ []
# broader conj deeper ADJ ADJ []
# relationships dobj build VERB NOUN [deeper, with]
# with prep relationships NOUN ADP [customers]
# their poss customers NOUN PRON []
# customers pobj with ADP NOUN [their]
# . punct be VERB PUNCT []
# In prep combine VERB ADP [term]
# the det term NOUN DET []
# near amod term NOUN ADJ []
# term pobj In ADP NOUN [the, near]
# , punct combine VERB PUNCT []
# these det shifts NOUN DET []
# shifts nsubj combine VERB NOUN [these]
# will aux combine VERB AUX []
# combine ROOT combine VERB VERB [In, ,, shifts, will, intensify, .]
# to aux intensify VERB PART []
# intensify advcl combine VERB VERB [to, competition, as, seek]
# competition dobj intensify VERB NOUN []
# as prep intensify VERB ADP [entrants]
# new amod entrants NOUN ADJ []
# entrants pobj as ADP NOUN [new, and, incumbents]
# and cc entrants NOUN CCONJ []
# incumbents conj entrants NOUN NOUN []
# seek advcl intensify VERB VERB [push]
# to aux push VERB PART []
# push xcomp seek VERB VERB [to, boundaries]
# past amod boundaries NOUN ADJ []
# traditional amod boundaries NOUN ADJ []
# boundaries dobj push VERB NOUN [past, traditional]
# . punct combine VERB PUNCT []
# More amod banks NOUN ADJ [than]
# than prep More ADJ SCONJ [ ]
#   pobj than SCONJ SPACE [ ]
# 100 nummod   SPACE NUM []
#   dobj   SPACE SPACE [100]
# digital amod banks NOUN ADJ []
# attacker compound banks NOUN NOUN []
# banks nsubj launched VERB NOUN [More, digital, attacker]
# have aux launched VERB AUX []
# launched ROOT launched VERB VERB [banks, have, in, globally, —, including, ;, launched, .]
# in prep launched VERB ADP [years]
# the det years NOUN DET []
# last amod years NOUN ADJ []
# few amod years NOUN ADJ []
# years pobj in ADP NOUN [the, last, few]
# globally advmod launched VERB ADV []
# — punct launched VERB PUNCT []
# including prep launched VERB VERB [N]
# N pobj including VERB PROPN [26, ,, Monzo, in]
# 26 nummod N PROPN NUM []
# , punct N PROPN PUNCT []
# Monzo conj N PROPN PROPN [and, Revolut]
# and cc Monzo PROPN CCONJ []
# Revolut conj Monzo PROPN PROPN []
# in prep N PROPN ADP [Europe]
# Europe pobj in ADP PROPN []
# ; punct launched VERB PUNCT [WeBank]
# WeBank nmod ; PUNCT PROPN [,, Digibank, Jenius, ;, SoFi, ;, Nubank, —]
# , punct WeBank PROPN PUNCT []
# Digibank appos WeBank PROPN PROPN [,]
# , punct Digibank PROPN PUNCT []
# Jenius appos WeBank PROPN PROPN [in]
# in prep Jenius PROPN ADP [Asia]
# Asia pobj in ADP PROPN []
# ; punct WeBank PROPN PUNCT []
# SoFi conj WeBank PROPN PROPN [,, Marcus]
# , punct SoFi PROPN PUNCT []
# Marcus conj SoFi PROPN PROPN [,, Moven]
# , punct Marcus PROPN PUNCT []
# Moven conj Marcus PROPN PROPN [in]
# in prep Moven PROPN ADP [US]
# the det US PROPN DET []
# US pobj in ADP PROPN [the]
# ; punct WeBank PROPN PUNCT []
# Nubank appos WeBank PROPN PROPN [in]
# in prep Nubank PROPN ADP [America]
# South compound America PROPN PROPN []
# America pobj in ADP PROPN [South]
# — punct WeBank PROPN PUNCT []
# while mark launched VERB SCONJ []
# many amod incumbents NOUN ADJ []
# incumbents nsubj launched VERB NOUN [many]
# have aux launched VERB AUX []
# launched advcl launched VERB VERB [while, incumbents, have, or, considering]
# or cc launched VERB CCONJ []
# are aux considering VERB AUX []
# considering conj launched VERB VERB [are, launching]
# launching xcomp considering VERB VERB [models]
# digital amod first ADJ ADJ []
# - punct first ADJ PUNCT []
# first amod models NOUN ADJ [digital, -]
# models dobj launching VERB NOUN [first]
# . punct launched VERB PUNCT []
# Over prep expect VERB ADP [years]
# the det years NOUN DET []
# next amod years NOUN ADJ []
# three quantmod five NUM NUM []
# to quantmod five NUM PART []
# five nummod years NOUN NUM [three, to]
# years pobj Over ADP NOUN [the, next, five]
# , punct expect VERB PUNCT []
# we nsubj expect VERB PRON []
# expect ROOT expect VERB VERB [Over, ,, we, emerge, .]
# a quantmod few ADJ DET []
# few nummod players NOUN ADJ [a]
# players nsubj emerge VERB NOUN [few]
# to aux emerge VERB PART []
# emerge ccomp expect VERB VERB [players, to, from, gain]
# from prep emerge VERB ADP [scrum]
# this det scrum NOUN DET []
# competitive amod scrum NOUN ADJ []
# scrum pobj from ADP NOUN [this, competitive]
# to aux gain VERB PART []
# gain advcl emerge VERB VERB [to, share, in, and, beyond]
# dominant amod share NOUN ADJ []
# share dobj gain VERB NOUN [dominant]
# in prep gain VERB ADP [markets]
# their poss markets NOUN PRON []
# core compound markets NOUN NOUN []
# markets pobj in ADP NOUN [their, core]
# and cc gain VERB CCONJ []
# possibly advmod beyond ADV ADV []
# beyond conj gain VERB ADV [possibly]
# . punct expect VERB PUNCT []
# These det firms NOUN DET []
# firms nsubj taken VERB NOUN [These]
# will aux taken VERB AUX []
# have aux taken VERB AUX []
# taken ROOT taken VERB VERB [firms, will, have, actions, capitalize, .]
# bold amod actions NOUN ADJ [and, decisive]
# and cc bold ADJ CCONJ []
# decisive conj bold ADJ ADJ []
# actions dobj taken VERB NOUN [bold]
# to aux capitalize VERB PART []
# capitalize advcl taken VERB VERB [to, on]
# on prep capitalize VERB ADP [shifts]
# the det shifts NOUN DET []
# shifts pobj on ADP NOUN [the, reshaping]
# that nsubj reshaping VERB DET []
# are aux reshaping VERB AUX []
# reshaping relcl shifts NOUN VERB [that, are, industry]
# the det industry NOUN DET []
# industry dobj reshaping VERB NOUN [the]
# . punct taken VERB PUNCT []
# In prep be VERB ADP [cases]
# some det cases NOUN DET []
# cases pobj In ADP NOUN [some]
# , punct be VERB PUNCT []
# these det winners NOUN DET []
# winners nsubj be VERB NOUN [these]
# will aux be VERB AUX []
# be ccomp be VERB VERB [In, ,, winners, will, incumbents]
# incumbents attr be VERB NOUN [build]
# that nsubj build VERB DET []
# build relcl incumbents NOUN VERB [that, on]
# on prep build VERB ADP [share]
# an det share NOUN DET []
# already advmod significant ADJ ADV []
# significant amod share NOUN ADJ [already]
# share pobj on ADP NOUN [an, significant]
# ; punct be VERB PUNCT []
# in prep be VERB ADP [others]
# others pobj in ADP NOUN []
# , punct be VERB PUNCT []
# they nsubj be VERB PRON []
# will aux be VERB AUX []
# be ROOT be VERB VERB [be, ;, in, ,, they, will, institutions, .]
# institutions attr be VERB NOUN [newer]
# newer amod institutions NOUN ADJ [to]
# to prep newer ADJ ADP [industry]
# the det industry NOUN DET []
# banking compound industry NOUN NOUN []
# industry pobj to ADP NOUN [the, banking, ,, use]
# , punct industry NOUN PUNCT []
# which nsubj use VERB DET []
# use relcl industry NOUN VERB [which, agility, attract]
# their poss agility NOUN PRON []
# agility dobj use VERB NOUN [their, ,, aggressiveness]
# , punct agility NOUN PUNCT []
# strategic amod aggressiveness NOUN ADJ []
# aggressiveness conj agility NOUN NOUN [strategic, ,, and, execution]
# , punct aggressiveness NOUN PUNCT []
# and cc aggressiveness NOUN CCONJ []
# sharp amod execution NOUN ADJ []
# execution conj aggressiveness NOUN NOUN [sharp]
# to aux attract VERB PART []
# attract xcomp use VERB VERB [to, customers]
# customers dobj attract VERB NOUN []
# . punct be VERB PUNCT []
# 1 ROOT 1 X X [.]
# . punct 1 X PUNCT []
# The det formula NOUN DET []
# traditional amod formula NOUN ADJ []
# distribution npadvmod led VERB NOUN []
# - punct led VERB PUNCT []
# led amod formula NOUN VERB [distribution, -]
# growth compound formula NOUN NOUN []
# formula nsubj applies VERB NOUN [The, traditional, led, growth]
# no neg longer ADV ADV []
# longer advmod applies VERB ADV [no]
# applies ccomp linked VERB VERB [formula, longer, Until]
# Until prep applies VERB ADP [crisis]
# the det crisis NOUN DET []
# financial amod crisis NOUN ADJ []
# crisis pobj Until ADP NOUN [the, financial, in, ,]
# in prep crisis NOUN ADP [ ]
#   pobj in ADP SPACE [2007]
# 2007 npadvmod   SPACE NUM []
# , punct crisis NOUN PUNCT []
# a det bank NOUN DET []
# retail amod bank NOUN ADJ []
# bank poss share NOUN NOUN [a, retail, ’s]
# ’s case bank NOUN PART []
# total amod share NOUN ADJ []
# share nsubjpass linked VERB NOUN [bank, total, of]
# of prep share NOUN ADP [deposits]
# deposits pobj of ADP NOUN []
# was auxpass linked VERB AUX []
# tightly advmod linked VERB ADV []
# linked ROOT linked VERB VERB [applies, share, was, tightly, to, .]
# to prep linked VERB ADP [size]
# the det size NOUN DET []
# size pobj to ADP NOUN [the, of]
# of prep size NOUN ADP [network]
# its poss network NOUN PRON []
# branch compound network NOUN NOUN []
# network pobj of ADP NOUN [its, branch]
# . punct linked VERB PUNCT []
# Even advmod grew VERB ADV []
# as mark grew VERB ADP []
# internet compound use NOUN NOUN []
# use nsubj grew VERB NOUN [internet]
# grew advcl visited VERB VERB [Even, as, use, rapidly]
# rapidly advmod grew VERB ADV []
# , punct visited VERB PUNCT []
# customers nsubj visited VERB NOUN []
# still advmod visited VERB ADV []
# visited ROOT visited VERB VERB [grew, ,, customers, still, branches, for, and, learn, .]
# branches dobj visited VERB NOUN []
# for prep visited VERB ADP [servicing]
# account compound servicing NOUN NOUN []
# servicing pobj for ADP NOUN [account]
# and cc visited VERB CCONJ []
# to aux learn VERB PART []
# learn conj visited VERB VERB [to, about, and, purchase]
# about prep learn VERB ADP []
# and cc learn VERB CCONJ []
# purchase conj learn VERB VERB [products]
# new amod products NOUN ADJ []
# products dobj purchase VERB NOUN [new]
# . punct visited VERB PUNCT []
# The det branch NOUN DET []
# physical amod branch NOUN ADJ []
# branch nsubj created VERB NOUN [The, physical]
# created ROOT created VERB VERB [branch, sense, .]
# a det sense NOUN DET []
# sense dobj created VERB NOUN [a, of]
# of prep sense NOUN ADP [security]
# security pobj of ADP NOUN [and, trust]
# and cc security NOUN CCONJ []
# trust conj security NOUN NOUN []
# . punct created VERB PUNCT []
# Banks nsubj benefited VERB NOUN [with]
# with prep Banks NOUN ADP [density]
# higher amod density NOUN ADJ []
# branch compound density NOUN NOUN []
# density pobj with ADP NOUN [higher, branch]
# benefited ROOT benefited VERB VERB [Banks, from, .]
# from prep benefited VERB ADP [effect]
# a det effect NOUN DET []
# network compound effect NOUN NOUN []
# effect pobj from ADP NOUN [a, network, —, branches]
# — punct effect NOUN PUNCT []
# the det branches NOUN DET []
# more amod branches NOUN ADJ []
# branches appos effect NOUN NOUN [the, more, ,, likelihood]
# , punct branches NOUN PUNCT []
# the advmod higher ADJ DET []
# higher amod likelihood NOUN ADJ [the]
# the det likelihood NOUN DET []
# likelihood conj branches NOUN NOUN [higher, the, of]
# of prep likelihood NOUN ADP [acquiring]
# acquiring pcomp of ADP VERB [and, retaining]
# and cc acquiring VERB CCONJ []
# retaining conj acquiring VERB VERB [customers]
# customers dobj retaining VERB NOUN []
# . punct benefited VERB PUNCT []
# Over prep weakened VERB ADP [decade]
# the det decade NOUN DET []
# past amod decade NOUN ADJ []
# decade pobj Over ADP NOUN [the, past]
# , punct weakened VERB PUNCT []
# this det relationship NOUN DET []
# relationship nsubj weakened VERB NOUN [this, between]
# between prep relationship NOUN ADP [growth]
# deposit compound growth NOUN NOUN []
# growth pobj between ADP NOUN [deposit, and, density]
# and cc growth NOUN CCONJ []
# branch compound density NOUN NOUN []
# density conj growth NOUN NOUN [branch]
# has aux weakened VERB AUX []
# weakened ROOT weakened VERB VERB [Over, ,, relationship, has, .]
# . punct weakened VERB PUNCT []
# Deposits nsubj doubled VERB NOUN [at]
# at prep Deposits NOUN ADP [banks]
# the det banks NOUN DET []
#   nmod banks NOUN SPACE [ ]
# 25 nummod   SPACE NUM []
#   dobj   SPACE SPACE [25]
# largest amod banks NOUN ADJ []
# US nmod banks NOUN PROPN []
# retail amod banks NOUN ADJ []
# banks pobj at ADP NOUN [the,  , largest, US, retail]
# have aux doubled VERB AUX []
# doubled ROOT doubled VERB VERB [Deposits, have, over, ,, shrank, .]
# over prep doubled VERB ADP [decade]
# the det decade NOUN DET []
# past amod decade NOUN ADJ []
# decade pobj over ADP NOUN [the, past]
# , punct doubled VERB PUNCT []
# while mark shrank VERB SCONJ []
# their poss footprint NOUN PRON []
# combined amod branch NOUN VERB []
# branch compound footprint NOUN NOUN [combined]
# footprint nsubj shrank VERB NOUN [their, branch]
# shrank advcl doubled VERB VERB [while, footprint, by, percent, over]
# by agent shrank VERB ADP [ ]
#   pobj by ADP SPACE []
# 15 nummod   SPACE NUM []
#   nummod percent NOUN SPACE [15]
# percent dobj shrank VERB NOUN [ ]
# over prep shrank VERB ADP [period]
# the det period NOUN DET []
# same amod period NOUN ADJ []
# period pobj over ADP NOUN [the, same]
# . punct doubled VERB PUNCT []
# This det correlation NOUN DET []
# reverse amod correlation NOUN ADJ []
# correlation nsubj is AUX NOUN [This, reverse]
# is ROOT is AUX AUX [correlation, sharper, for, —, reducing, increased, .]
# even advmod sharper ADJ ADV []
# sharper acomp is AUX ADJ [even]
# for prep is AUX ADP [banks]
# the det banks NOUN DET []
# top amod banks NOUN ADJ []
# five nummod banks NOUN NUM []
# US compound banks NOUN PROPN []
# banks pobj for ADP NOUN [the, top, five, US]
# — punct is AUX PUNCT []
# while mark reducing VERB SCONJ []
# reducing advcl is AUX VERB [while, branches, by]
# branches dobj reducing VERB NOUN []
# by prep reducing VERB ADP [percent]
#   nmod percent NOUN SPACE []
# 15 nummod   SPACE NUM []
#   nummod percent NOUN SPACE [15]
# percent pobj by ADP NOUN [ ,  ]
# , punct increased VERB PUNCT []
# they nsubj increased VERB PRON []
# increased conj is AUX VERB [,, they, deposits, by, (,  , )]
# deposits dobj increased VERB NOUN []
# by prep increased VERB ADP [ ]
#   pobj by ADP SPACE [times]
# 2.6 nummod   SPACE NUM []
#   nummod times NOUN SPACE [2.6]
# times npadvmod   SPACE NOUN [ ]
# ( punct increased VERB PUNCT []
# Exhibit compound   SPACE NOUN []
#   dep increased VERB SPACE [Exhibit, 1]
# 1 nummod   SPACE NUM []
# ) punct increased VERB PUNCT []
# . punct is AUX PUNCT []
# While mark been VERB SCONJ []
# there expl been VERB PRON []
# have aux been VERB AUX []
# been advcl tied VERB VERB [While, there, have, periods]
# previous amod periods NOUN ADJ []
# periods attr been VERB NOUN [previous, of]
# of prep periods NOUN ADP [contraction]
# branch compound contraction NOUN NOUN []
# contraction pobj of ADP NOUN [branch]
# , punct tied VERB PUNCT []
# they nsubjpass tied VERB PRON []
# were auxpass tied VERB AUX []
# clearly advmod tied VERB ADV []
# tied ccomp commenced VERB VERB [been, ,, they, were, clearly, to]
# to prep tied VERB ADP [downturns]
# economic amod downturns NOUN ADJ []
# downturns pobj to ADP NOUN [economic]
# ; punct commenced VERB PUNCT []
# this det wave NOUN DET []
# most advmod recent ADJ ADV []
# recent amod wave NOUN ADJ [most]
# wave nsubj commenced VERB NOUN [this, recent, of]
# of prep wave NOUN ADP [retrenchment]
# retrenchment pobj of ADP NOUN []
# commenced ROOT commenced VERB VERB [tied, ;, wave, ago, and, persisted, .]
# about advmod a DET ADP []
# a nummod decade NOUN DET [about]
# decade npadvmod ago ADV NOUN [a]
# ago advmod commenced VERB ADV [decade]
# and cc commenced VERB CCONJ []
# has aux persisted VERB AUX []
# persisted conj commenced VERB VERB [has, through]
# through prep persisted VERB ADP [period]
# a det period NOUN DET []
# period pobj through ADP NOUN [a, of]
# of prep period NOUN ADP [growth]
# robust amod growth NOUN ADJ []
# economic amod growth NOUN ADJ []
# growth pobj of ADP NOUN [robust, economic]
# . punct commenced VERB PUNCT []
# Retail amod branch NOUN ADJ []
# banking compound branch NOUN NOUN []
# branch compound networks NOUN NOUN [Retail, banking]
# networks nsubj contracting VERB NOUN [branch]
# are aux contracting VERB AUX []
# contracting ROOT contracting VERB VERB [networks, are, across, ,, varies, .]
# across prep contracting VERB ADP [America]
# North compound America PROPN PROPN []
# America pobj across ADP PROPN [North, ,, UK, Exhibit]
# , punct America PROPN PUNCT []
# the det UK PROPN DET []
# UK conj America PROPN PROPN [the, ,, and, Europe]
# , punct UK PROPN PUNCT []
# and cc UK PROPN CCONJ []
# Europe conj UK PROPN PROPN [(]
# ( punct Europe PROPN PUNCT []
# Exhibit conj America PROPN NOUN [ ,  , )]
#   appos Exhibit NOUN SPACE [2, ,]
# 2 nummod   SPACE NUM []
# , punct   SPACE PUNCT []
# page compound   SPACE NOUN []
#   appos Exhibit NOUN SPACE [page, 4]
# 4 appos   SPACE NUM []
# ) punct Exhibit NOUN PUNCT []
# , punct contracting VERB PUNCT []
# although mark varies VERB SCONJ []
# the det pace NOUN DET []
# pace nsubj varies VERB NOUN [the, of]
# of prep pace NOUN ADP [change]
# change pobj of ADP NOUN []
# varies advcl contracting VERB VERB [although, pace, considerably, between]
# considerably advmod varies VERB ADV []
# between prep varies VERB ADP [regions]
# regions pobj between ADP NOUN []
# . punct contracting VERB PUNCT []
# Those nsubj reduced VERB DET [are]
# that nsubj are VERB DET []
# are relcl Those DET VERB [that, ahead]
# ahead advmod are VERB ADV [of]
# of prep ahead ADV ADP [curve]
# the det curve NOUN DET []
# curve pobj of ADP NOUN [the]
# have aux reduced VERB AUX []
# reduced ROOT reduced VERB VERB [Those, have, branches, by, .]
# branches dobj reduced VERB NOUN []
# by prep reduced VERB ADP [much]
# as advmod much ADJ ADV []
# much pobj by ADP ADJ [as, as]
# as prep much ADJ ADP [percent]
#   nmod percent NOUN SPACE []
# 71 nummod   SPACE NUM []
#   nummod percent NOUN SPACE [71]
# percent pobj as ADP NOUN [ ,  , Netherlands, )]
# ( punct Netherlands PROPN PUNCT []
# Netherlands appos percent NOUN PROPN [(]
# ) punct percent NOUN PUNCT []
# . punct reduced VERB PUNCT []
# Banks nsubj are AUX NOUN [in]
# in prep Banks NOUN ADP [America]
# North compound America PROPN PROPN []
# America pobj in ADP PROPN [North, and, Europe]
# and cc America PROPN CCONJ []
# Southern compound Europe PROPN PROPN []
# Europe conj America PROPN PROPN [Southern]
# are ROOT are AUX AUX [Banks,  , Rewriting, :, Succeeding, .]
#   attr are AUX SPACE [3]
# 3 nummod   SPACE NUM []
# Rewriting advcl are AUX VERB [rules]
# the det rules NOUN DET []
# rules dobj Rewriting VERB NOUN [the]
# : punct are AUX PUNCT []
# Succeeding advcl are AUX VERB [in, sales]
# in prep Succeeding VERB ADP [landscape]
# the det landscape NOUN DET []
# new amod landscape NOUN ADJ []
# retail amod banking NOUN ADJ []
# banking compound landscape NOUN NOUN [retail]
# landscape pobj in ADP NOUN [the, new, banking, reducing]
# reducing acl landscape NOUN VERB [branches, and]
# branches dobj reducing VERB NOUN []
# and cc reducing VERB CCONJ []
# growing amod sales NOUN VERB []
# digital amod sales NOUN ADJ []
# sales dobj Succeeding VERB NOUN [growing, digital, at]
# at prep sales NOUN ADP [rate]
# a det rate NOUN DET []
# more advmod gradual ADJ ADV []
# gradual amod rate NOUN ADJ [more]
# rate pobj at ADP NOUN [a, gradual]
# . punct are AUX PUNCT []
# In prep is AUX ADP [countries]
# many amod countries NOUN ADJ []
# Asian amod countries NOUN ADJ [,, African]
# , punct Asian ADJ PUNCT []
# African conj Asian ADJ ADJ [,, and, American]
# , punct African ADJ PUNCT []
# and cc African ADJ CCONJ []
# Latin amod American ADJ ADJ []
# American conj African ADJ ADJ [Latin]
# countries pobj In ADP NOUN [many, Asian]
# , punct is AUX PUNCT []
# branch compound reduction NOUN NOUN []
# reduction nsubj is AUX NOUN [branch]
# is ROOT is AUX AUX [In, ,, reduction, not, apparent, —, leapfrogged, .]
# not neg is AUX PART []
# so advmod apparent ADJ ADV []
# apparent acomp is AUX ADJ [so]
# — punct is AUX PUNCT []
# only advmod leapfrogged VERB ADV []
# because mark leapfrogged VERB SCONJ []
# retail amod banks NOUN ADJ []
# banks nsubj leapfrogged VERB NOUN [retail, in]
# in prep banks NOUN ADP [markets]
# these det markets NOUN DET []
# markets pobj in ADP NOUN [these]
# leapfrogged advcl is AUX VERB [only, because, banks, distribution, go]
# branch compound distribution NOUN NOUN []
# distribution dobj leapfrogged VERB NOUN [branch]
# to aux go VERB PART []
# go advcl leapfrogged VERB VERB [to, directly, to]
# directly advmod go VERB ADV []
# to prep go VERB ADP [sales]
# digital amod sales NOUN ADJ []
# sales pobj to ADP NOUN [digital]
# . punct is AUX PUNCT []
# The det rate NOUN DET []
# rate nsubjpass tied VERB NOUN [The, of]
# of prep rate NOUN ADP [reduction]
# branch compound reduction NOUN NOUN []
# reduction pobj of ADP NOUN [branch]
# is auxpass tied VERB AUX []
# often advmod tied VERB ADV []
# tied ROOT tied VERB VERB [rate, is, often, to, .]
# to prep tied VERB ADP [willingness]
# customer compound willingness NOUN NOUN []
# willingness pobj to ADP NOUN [customer, purchase]
# to aux purchase VERB PART []
# purchase acl willingness NOUN VERB [to, products, online]
# banking compound products NOUN NOUN []
# products dobj purchase VERB NOUN [banking]
# online advmod purchase VERB ADV [or, on]
# or cc online ADV CCONJ []
# on conj online ADV ADP [devices]
# mobile amod devices NOUN ADJ []
# devices pobj on ADP NOUN [mobile]
# . punct tied VERB PUNCT []
# Eighty quantmod ninety NUM NUM []
# to quantmod ninety NUM PART []
# ninety nummod percent NOUN NUM [Eighty, to]
# percent nsubj are AUX NOUN [ninety, of, in]
# of prep percent NOUN ADP [customers]
# banking compound customers NOUN NOUN []
# customers pobj of ADP NOUN [banking]
# in prep percent NOUN ADP [Nordics]
# the det Nordics PROPN DET []
# Nordics pobj in ADP PROPN [the]
# , punct are AUX PUNCT []
# for prep are AUX ADP [example]
# example pobj for ADP NOUN []
# , punct are AUX PUNCT []
# are ROOT are AUX AUX [percent, ,, for, ,, open, ,, compared, page, .]
# open acomp are AUX ADJ [to]
# to prep open ADJ ADP [purchases]
# digital amod purchases NOUN ADJ []
# product compound purchases NOUN NOUN []
# purchases pobj to ADP NOUN [digital, product, for]
# for prep purchases NOUN ADP [products]
# most amod products NOUN ADJ []
# financial amod products NOUN ADJ []
# products pobj for ADP NOUN [most, financial]
# , punct are AUX PUNCT []
# compared prep are AUX VERB [to, to]
# to prep compared VERB ADP [ ]
#   pobj to ADP SPACE [ ]
# 50 nummod   SPACE NUM []
#   appos   SPACE SPACE [50]
# to prep compared VERB ADP [percent]
#   nmod percent NOUN SPACE []
# 60 nummod   SPACE NUM []
#   nummod percent NOUN SPACE [60]
# percent pobj to ADP NOUN [ ,  , in,  ]
# in prep percent NOUN ADP [America]
# North compound America PROPN PROPN []
# America pobj in ADP PROPN [North, and, Europe]
# and cc America PROPN CCONJ []
# Southern compound Europe PROPN PROPN []
# Europe conj America PROPN PROPN [Southern]
# ( punct   SPACE PUNCT []
# Exhibit compound   SPACE NOUN []
#   appos percent NOUN SPACE [(, Exhibit, 3, ,]
# 3 nummod   SPACE NUM []
# , punct   SPACE PUNCT []
# page dep are AUX NOUN [ , 5, )]
#   nummod page NOUN SPACE []
# 5 nummod page NOUN NUM []
# ) punct page NOUN PUNCT []
# . punct are AUX PUNCT []
# While mark willingness NOUN SCONJ []
# customer nsubj willingness NOUN NOUN []
# willingness nsubj varies VERB NOUN [While, customer, purchase]
# to aux purchase VERB PART []
# purchase acl willingness NOUN VERB [to, products, via]
# products dobj purchase VERB NOUN []
# via prep purchase VERB ADP [channels]
# digital amod channels NOUN ADJ []
# channels pobj via ADP NOUN [digital]
# varies advcl is AUX VERB [willingness]
# , punct is AUX PUNCT []
# however advmod is AUX ADV []
# , punct is AUX PUNCT []
# the det thread NOUN DET []
# common amod thread NOUN ADJ []
# thread nsubj is AUX NOUN [the, common]
# is ROOT is AUX AUX [varies, ,, however, ,, thread, is, .]
# that mark is AUX SCONJ []
# in prep is AUX ADP [markets]
# all det markets NOUN DET []
# markets pobj in ADP NOUN [all]
# this det readiness NOUN DET []
# readiness nsubj is AUX NOUN [this]
# is ccomp is AUX AUX [that, in, readiness, ahead, and, require]
# far advmod ahead ADV ADV []
# ahead advmod is AUX ADV [far, of]
# of prep ahead ADV ADP [sales]
# actual amod sales NOUN ADJ []
# digital amod sales NOUN ADJ []
# sales pobj of ADP NOUN [actual, digital]
# and cc is AUX CCONJ []
# will aux require VERB AUX []
# require conj is AUX VERB [will, banks, catch]
# banks dobj require VERB NOUN []
# to aux catch VERB PART []
# catch xcomp require VERB VERB [to, up, to]
# up prt catch VERB ADP []
# to prep catch VERB ADP [needs]
# consumer compound needs NOUN NOUN []
# needs pobj to ADP NOUN [consumer, and, expectations]
# and cc needs NOUN CCONJ []
# expectations conj needs NOUN NOUN []
# . punct is AUX PUNCT []

# %% [markdown]
# ### get sentence descriptions

# %%
for sentence in sentences:
  doc = nlp(sentence)
  descriptive_term = ''
  for token in doc:
    if token.pos_ == 'ADJ':
      prepend = ''
      for child in token.children:
        if child.pos_ != 'ADV':
          continue
        prepend += child.text + ' '
      descriptive_term = prepend + token.text
  print(sentence)
  print(descriptive_term)
# Out:
# Succeeding in the new retail banking landscape Retail banks have long competed on distribution, realizing economies of scale through network effects and investments in brand and infrastructure.
# Retail
# But even those scale economies had limits above a certain size.
# certain
# As a result, in most retail banking markets, a few large institutions, operating at similar efficiency ratios, dominate market share.
# similar
# Changes to the retail banking business model have mostly come in response to regulatory shifts, as opposed to a purposeful reimagining of what the winning bank of the future will look like.
# purposeful
# Retail banks have also not kept pace with the improvements in customer experience seen in other consumer industries.
# other
# Few banks stand out for innovation in customer interaction models or branch formats.
# Few
# Marketing investments have traditionally focused on brand building and increasing loyalty: a reputable brand stood for trust and security and became a moat, providing protection against new entrants to the sector.
# new
# Finally, most banks offer similar products, with limited innovation in features.
# limited
# Today, the moats that banks have built are more likely to restrict their own progress than protect them from attackers.
# own
# Four shifts are reshaping the global retail banking landscape to the point where banks need to fundamentally rethink what it takes to compete and win.
# retail
# This should be an urgent priority for banks.
# urgent
# The pace of change will likely accelerate, with a select set of large-scale winners emerging in the next three to five years that will gain share in their core markets and begin to compete across borders, leaving many sub-scale institutions scrambling for relevance.
# scale
# Rewriting the rules: Succeeding in the new retail banking landscape  2 Rewriting the rules: Succeeding in the new retail banking landscape Four shifts are reshaping retail banking Four secular shifts are changing the way retail banks will compete in the coming years:    The traditional distribution-led growth formula is losing relevance, with a breakdown in the relationship between branch footprint and growth.
# traditional
# Banks are now competing on customer experience, with leaders growing faster than their competitors.
#
# Scale economics are back—banks that excel at deploying new technologies (e.g., automation and machine learning) and those with a more digital-centric channel mix will have a structural cost advantage.
# structural
# The retail banking relationship is getting unbundled along product lines, fueled by digitization and, increasingly, by regulation— and the biggest profit pools are under attack.
# biggest
# A few banks will be able to temper and reverse this trend, using superior data and analytics capabilities to build deeper and broader relationships with their customers.
# broader
# In the near term, these shifts will combine to intensify competition as new entrants and incumbents seek to push past traditional boundaries.
# traditional
# More than  100  digital attacker banks have launched in the last few years globally— including N 26 , Monzo and Revolut in Europe; WeBank, Digibank, Jenius in Asia; SoFi, Marcus, Moven in the US; Nubank in South America— while many incumbents have launched or are considering launching digital-first models.
# first
# Over the next three to five years, we expect a few players to emerge from this competitive scrum to gain dominant share in their core markets and possibly beyond.
# dominant
# These firms will have taken bold and decisive actions to capitalize on the shifts that are reshaping the industry.
# decisive
# In some cases, these winners will be incumbents that build on an already significant share; in others, they will be institutions newer to the banking industry, which use their agility, strategic aggressiveness, and sharp execution to attract customers.
# sharp
# 1 .
#
# The traditional distribution-led growth formula no longer applies Until the financial crisis in  2007 , a retail bank’s total share of deposits was tightly linked to the size of its branch network.
# total
# Even as internet use grew rapidly, customers still visited branches for account servicing and to learn about and purchase new products.
# new
# The physical branch created a sense of security and trust.
# physical
# Banks with higher branch density benefited from a network effect—the more branches, the higher the likelihood of acquiring and retaining customers.
# higher
# Over the past decade, this relationship between deposit growth and branch density has weakened.
# past
# Deposits at the  25  largest US retail banks have doubled over the past decade, while their combined branch footprint shrank by  15  percent over the same period.
# same
# This reverse correlation is even sharper for the top five US banks—while reducing branches by  15  percent, they increased deposits by  2.6  times ( Exhibit  1 ).
# top
# While there have been previous periods of branch contraction, they were clearly tied to economic downturns; this most recent wave of retrenchment commenced about a decade ago and has persisted through a period of robust economic growth.
# economic
# Retail banking branch networks are contracting across North America, the UK, and Europe (Exhibit  2 , page  4 ), although the pace of change varies considerably between regions.
# Retail
# Those that are ahead of the curve have reduced branches by as much as  71  percent (Netherlands).
# as much
# Banks in North America and Southern Europe are  3 Rewriting the rules: Succeeding in the new retail banking landscape reducing branches and growing digital sales at a more gradual rate.
# more gradual
# In many Asian, African, and Latin American countries, branch reduction is not so apparent—only because retail banks in these markets leapfrogged branch distribution to go directly to digital sales.
# digital
# The rate of branch reduction is often tied to customer willingness to purchase banking products online or on mobile devices.
# mobile
# Eighty to ninety percent of banking customers in the Nordics, for example, are open to digital product purchases for most financial products, compared to  50  to  60  percent in North America and Southern Europe ( Exhibit  3 , page  5 ).
# financial
# While customer willingness to purchase products via digital channels varies, however, the common thread is that in all markets this readiness is far ahead of actual digital sales and will require banks to catch up to consumer needs and expectations.
# digital

# %% [markdown]
# ### identify the targets/aspects

# %%
aspects = []
for sentence in sentences:
  doc = nlp(sentence)
  descriptive_term = ''
  target = ''
  for token in doc:
    if token.dep_ == 'nsubj' and token.pos_ == 'NOUN':
      target = token.text
    if token.pos_ == 'ADJ':
      prepend = ''
      for child in token.children:
        if child.pos_ != 'ADV':
          continue
        prepend += child.text + ' '
      descriptive_term = prepend + token.text
  aspects.append({'aspect': target,
    'description': descriptive_term})


#print(aspects)
pprint.pprint(aspects)
# Out:
# [{'aspect': 'banks', 'description': 'Retail'},
#  {'aspect': 'economies', 'description': 'certain'},
#  {'aspect': 'institutions', 'description': 'similar'},
#  {'aspect': 'bank', 'description': 'purposeful'},
#  {'aspect': 'banks', 'description': 'other'},
#  {'aspect': 'banks', 'description': 'Few'},
#  {'aspect': 'brand', 'description': 'new'},
#  {'aspect': 'banks', 'description': 'limited'},
#  {'aspect': 'banks', 'description': 'own'},
#  {'aspect': 'banks', 'description': 'retail'},
#  {'aspect': '', 'description': 'urgent'},
#  {'aspect': 'pace', 'description': 'scale'},
#  {'aspect': 'formula', 'description': 'traditional'},
#  {'aspect': 'leaders', 'description': ''},
#  {'aspect': 'economics', 'description': 'structural'},
#  {'aspect': 'pools', 'description': 'biggest'},
#  {'aspect': 'banks', 'description': 'broader'},
#  {'aspect': 'shifts', 'description': 'traditional'},
#  {'aspect': 'incumbents', 'description': 'first'},
#  {'aspect': 'players', 'description': 'dominant'},
#  {'aspect': 'firms', 'description': 'decisive'},
#  {'aspect': 'winners', 'description': 'sharp'},
#  {'aspect': '', 'description': ''},
#  {'aspect': 'formula', 'description': 'total'},
#  {'aspect': 'customers', 'description': 'new'},
#  {'aspect': 'branch', 'description': 'physical'},
#  {'aspect': 'Banks', 'description': 'higher'},
#  {'aspect': 'relationship', 'description': 'past'},
#  {'aspect': 'footprint', 'description': 'same'},
#  {'aspect': 'correlation', 'description': 'top'},
#  {'aspect': 'wave', 'description': 'economic'},
#  {'aspect': 'pace', 'description': 'Retail'},
#  {'aspect': '', 'description': 'as much'},
#  {'aspect': 'Banks', 'description': 'more gradual'},
#  {'aspect': 'banks', 'description': 'digital'},
#  {'aspect': '', 'description': 'mobile'},
#  {'aspect': 'percent', 'description': 'financial'},
#  {'aspect': 'readiness', 'description': 'digital'}]

# %% [markdown]
# ### find sentiments on aspects

# %%
for aspect in aspects:
  aspect['sentiment'] = TextBlob(aspect['description']).sentiment
pprint.pprint(aspects)
# Out:
# [{'aspect': 'banks',
#   'description': 'Retail',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'economies',
#   'description': 'certain',
#   'sentiment': Sentiment(polarity=0.21428571428571427, subjectivity=0.5714285714285714)},
#  {'aspect': 'institutions',
#   'description': 'similar',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.4)},
#  {'aspect': 'bank',
#   'description': 'purposeful',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'banks',
#   'description': 'other',
#   'sentiment': Sentiment(polarity=-0.125, subjectivity=0.375)},
#  {'aspect': 'banks',
#   'description': 'Few',
#   'sentiment': Sentiment(polarity=-0.2, subjectivity=0.1)},
#  {'aspect': 'brand',
#   'description': 'new',
#   'sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)},
#  {'aspect': 'banks',
#   'description': 'limited',
#   'sentiment': Sentiment(polarity=-0.07142857142857142, subjectivity=0.14285714285714285)},
#  {'aspect': 'banks',
#   'description': 'own',
#   'sentiment': Sentiment(polarity=0.6, subjectivity=1.0)},
#  {'aspect': 'banks',
#   'description': 'retail',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': '',
#   'description': 'urgent',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'pace',
#   'description': 'scale',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'formula',
#   'description': 'traditional',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.75)},
#  {'aspect': 'leaders',
#   'description': '',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'economics',
#   'description': 'structural',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'pools',
#   'description': 'biggest',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'banks',
#   'description': 'broader',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'shifts',
#   'description': 'traditional',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.75)},
#  {'aspect': 'incumbents',
#   'description': 'first',
#   'sentiment': Sentiment(polarity=0.25, subjectivity=0.3333333333333333)},
#  {'aspect': 'players',
#   'description': 'dominant',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'firms',
#   'description': 'decisive',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'winners',
#   'description': 'sharp',
#   'sentiment': Sentiment(polarity=-0.125, subjectivity=0.75)},
#  {'aspect': '',
#   'description': '',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'formula',
#   'description': 'total',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.75)},
#  {'aspect': 'customers',
#   'description': 'new',
#   'sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)},
#  {'aspect': 'branch',
#   'description': 'physical',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.14285714285714285)},
#  {'aspect': 'Banks',
#   'description': 'higher',
#   'sentiment': Sentiment(polarity=0.25, subjectivity=0.5)},
#  {'aspect': 'relationship',
#   'description': 'past',
#   'sentiment': Sentiment(polarity=-0.25, subjectivity=0.25)},
#  {'aspect': 'footprint',
#   'description': 'same',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.125)},
#  {'aspect': 'correlation',
#   'description': 'top',
#   'sentiment': Sentiment(polarity=0.5, subjectivity=0.5)},
#  {'aspect': 'wave',
#   'description': 'economic',
#   'sentiment': Sentiment(polarity=0.2, subjectivity=0.2)},
#  {'aspect': 'pace',
#   'description': 'Retail',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': '',
#   'description': 'as much',
#   'sentiment': Sentiment(polarity=0.2, subjectivity=0.2)},
#  {'aspect': 'Banks',
#   'description': 'more gradual',
#   'sentiment': Sentiment(polarity=0.5, subjectivity=0.5)},
#  {'aspect': 'banks',
#   'description': 'digital',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': '',
#   'description': 'mobile',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'percent',
#   'description': 'financial',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'readiness',
#   'description': 'digital',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)}]

# %% [markdown]
# ### Using spaCy for SA

# %%
# This is not ABSA!!
from textblob import TextBlob

#nlp = spacy.load('en_core_web_sm')
#print(nlp.pipe_names)
#nlp.add_pipe('spacytextblob')

_table = []

for sentence in sentences:
    _row = []
    blob = TextBlob(sentence)
    _row.append(sentence)
    _row.append(blob.sentiment_assessments.polarity)
    _row.append(blob.sentiment_assessments.subjectivity)
    _row.append(blob.sentiment_assessments.assessments)
    _table.append(_row)

    
pd.DataFrame(_table, columns=["SENTENCE", "POLARITY", "SUBJECTIVITY", "ASSESSMENTS"])
# Out:
#                                              SENTENCE  POLARITY  SUBJECTIVITY  \
# 0   Succeeding in the new retail banking landscape...  0.043182      0.427273
# 1   But even those scale economies had limits abov...  0.107143      0.335714
# 2   As a result, in most retail banking markets, a...  0.128571      0.357143
# 3   Changes to the retail banking business model h...  0.333333      0.458333
# 4   Retail banks have also not kept pace with the ... -0.125000      0.375000
# 5   Few banks stand out for innovation in customer... -0.200000      0.100000
# 6   Marketing investments have traditionally focus...  0.212121      0.668182
# 7   Finally, most banks offer similar products, wi...  0.142857      0.347619
# 8   Today, the moats that banks have built are mor...  0.366667      0.833333
# 9   Four shifts are reshaping the global retail ba...  0.400000      0.200000
# 10       This should be an urgent priority for banks.  0.000000      0.000000
# 11  The pace of change will likely accelerate, wit...  0.166667      0.500000
# 12  Rewriting the rules: Succeeding in the new ret...  0.090909      0.553030
# 13  Banks are now competing on customer experience...  0.000000      0.000000
# 14  Scale economics are back—banks that excel at d...  0.318182      0.477273
# 15  The retail banking relationship is getting unb...  0.000000      0.000000
# 16  A few banks will be able to temper and reverse...  0.333333      0.541667
# 17  In the near term, these shifts will combine to... -0.003409      0.463636
# 18  More than  100  digital attacker banks have la...  0.160000      0.233333
# 19  Over the next three to five years, we expect a... -0.066667      0.366667
# 20  These firms will have taken bold and decisive ...  0.333333      0.666667
# 21  In some cases, these winners will be incumbent...  0.125000      0.812500
# 22                                                1 .  0.000000      0.000000
# 23  The traditional distribution-led growth formul... -0.044643      0.446429
# 24  Even as internet use grew rapidly, customers s...  0.136364      0.454545
# 25  The physical branch created a sense of securit...  0.000000      0.142857
# 26  Banks with higher branch density benefited fro...  0.333333      0.500000
# 27  Over the past decade, this relationship betwee... -0.250000      0.250000
# 28  Deposits at the  25  largest US retail banks h... -0.125000      0.187500
# 29  This reverse correlation is even sharper for t...  0.500000      0.500000
# 30  While there have been previous periods of bran...  0.138889      0.283333
# 31  Retail banking branch networks are contracting...  0.100000      0.450000
# 32  Those that are ahead of the curve have reduced...  0.200000      0.200000
# 33  Banks in North America and Southern Europe are...  0.159091      0.238636
# 34  In many Asian, African, and Latin American cou...  0.100000      0.100000
# 35  The rate of branch reduction is often tied to ...  0.000000      0.000000
# 36  Eighty to ninety percent of banking customers ...  0.100000      0.200000
# 37  While customer willingness to purchase product... -0.040000      0.320000
#
#                                           ASSESSMENTS
# 0   [([new], 0.13636363636363635, 0.45454545454545...
# 1   [([above], 0.0, 0.1, None), ([certain], 0.2142...
# 2   [([most], 0.5, 0.5, None), ([few], -0.2, 0.1, ...
# 3   [([mostly], 0.5, 0.5, None), ([winning], 0.5, ...
# 4                    [([other], -0.125, 0.375, None)]
# 5                          [([few], -0.2, 0.1, None)]
# 6   [([traditionally], 0.0, 0.75, None), ([reputab...
# 7   [([finally, most], 0.5, 0.5, None), ([similar]...
# 8   [([more], 0.5, 0.5, None), ([likely], 0.0, 1.0...
# 9   [([global], 0.0, 0.0, None), ([win], 0.8, 0.4,...
# 10                                                 []
# 11  [([likely], 0.0, 1.0, None), ([next], 0.0, 0.0...
# 12  [([new], 0.13636363636363635, 0.45454545454545...
# 13                                                 []
# 14  [([new], 0.13636363636363635, 0.45454545454545...
# 15                                                 []
# 16  [([few], -0.2, 0.1, None), ([able], 0.5, 0.625...
# 17  [([near], 0.1, 0.4, None), ([new], 0.136363636...
# 18  [([more], 0.5, 0.5, None), ([digital], 0.0, 0....
# 19  [([next], 0.0, 0.0, None), ([few], -0.2, 0.1, ...
# 20  [([bold], 0.3333333333333333, 0.66666666666666...
# 21  [([significant], 0.375, 0.875, None), ([sharp]...
# 22                                                 []
# 23  [([traditional], 0.0, 0.75, None), ([financial...
# 24  [([new], 0.13636363636363635, 0.45454545454545...
# 25     [([physical], 0.0, 0.14285714285714285, None)]
# 26  [([higher], 0.25, 0.5, None), ([more], 0.5, 0....
# 27                      [([past], -0.25, 0.25, None)]
# 28  [([past], -0.25, 0.25, None), ([same], 0.0, 0....
# 29                          [([top], 0.5, 0.5, None)]
# 30  [([previous], -0.16666666666666666, 0.16666666...
# 31                [([considerably], 0.1, 0.45, None)]
# 32                         [([much], 0.2, 0.2, None)]
# 33  [([southern], 0.0, 0.0, None), ([new], 0.13636...
# 34  [([many], 0.5, 0.5, None), ([asian], 0.0, 0.0,...
# 35                                                 []
# 36  [([open], 0.0, 0.5, None), ([digital], 0.0, 0....
# 37  [([digital], 0.0, 0.0, None), ([common], -0.3,...
